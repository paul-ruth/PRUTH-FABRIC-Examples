# %% [markdown]
# # Hello, FABRIC: Create Your First FABRIC Experiment
#
# This Jupyter notebook will walk you through creating your first FABRIC experiment. The "Hello, FABRIC" experiment tests the configuration of your environment to ensure you can create and access resources on FABRIC.  Specifically, the experiment deploys a slice of resources with a single virtual machine and confirms you can log into the virtual machine using FABLib methods.
#
# ## Step 1:  Configure the Environment
#
# Before running this notebook, you will need to configure your environment using the [Configure Environment](./configure_environment.ipynb) notebook. Please stop here, open and run that notebook, then return to this notebook.
#
# If you are using the FABRIC JupyterHub many of the environment variables will be automatically configured for you.  You will still need to set your bastion username, upload your bastion private key, and set the path to where you put your bastion private key. Your bastion username and private key should already be in your possession.
#
# If you are using the FABRIC API outside of the JupyterHub you will need to configure all of the environment variables. Defaults below will be correct in many situations but you will need to confirm your configuration.  If you have questions about this configuration, please contact the FABRIC admins using the [FABRIC User Forum](https://learn.fabric-testbed.net/forums/)
#
# More information about accessing your experiments through the FABRIC bastion hosts can be found [here](https://learn.fabric-testbed.net/knowledge-base/logging-into-fabric-vms/).

# %% [markdown]
# ## Step 2: Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
#fablib.show_config(output='jupyter', fields=['bastion_username','slice_private_key_file','bastion_public_addr'])
fablib.show_config()
# Out:
# <style type="text/css">
# #T_529b5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_529b5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_529b5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_529b5_row0_col0, #T_529b5_row0_col1, #T_529b5_row1_col0, #T_529b5_row1_col1, #T_529b5_row2_col0, #T_529b5_row2_col1, #T_529b5_row3_col0, #T_529b5_row3_col1, #T_529b5_row4_col0, #T_529b5_row4_col1, #T_529b5_row5_col0, #T_529b5_row5_col1, #T_529b5_row6_col0, #T_529b5_row6_col1, #T_529b5_row7_col0, #T_529b5_row7_col1, #T_529b5_row8_col0, #T_529b5_row8_col1, #T_529b5_row9_col0, #T_529b5_row9_col1, #T_529b5_row10_col0, #T_529b5_row10_col1, #T_529b5_row11_col0, #T_529b5_row11_col1, #T_529b5_row12_col0, #T_529b5_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_529b5">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_529b5_row0_col0" class="data row0 col0" >credmgr_host</td>
#       <td id="T_529b5_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row1_col0" class="data row1 col0" >orchestrator_host</td>
#       <td id="T_529b5_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row2_col0" class="data row2 col0" >fabric_token</td>
#       <td id="T_529b5_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row3_col0" class="data row3 col0" >project_id</td>
#       <td id="T_529b5_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row4_col0" class="data row4 col0" >bastion_username</td>
#       <td id="T_529b5_row4_col1" class="data row4 col1" >pruth_0000000529</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row5_col0" class="data row5 col0" >bastion_key_filename</td>
#       <td id="T_529b5_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row6_col0" class="data row6 col0" >bastion_public_addr</td>
#       <td id="T_529b5_row6_col1" class="data row6 col1" >bastion-1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row7_col0" class="data row7 col0" >bastion_passphrase</td>
#       <td id="T_529b5_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row8_col0" class="data row8 col0" >slice_public_key_file</td>
#       <td id="T_529b5_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row9_col0" class="data row9 col0" >slice_private_key_file</td>
#       <td id="T_529b5_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row10_col0" class="data row10 col0" >fabric_slice_private_key_passphrase</td>
#       <td id="T_529b5_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row11_col0" class="data row11 col0" >fablib_log_file</td>
#       <td id="T_529b5_row11_col1" class="data row11 col1" >fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row12_col0" class="data row12 col0" >fablib_log_level</td>
#       <td id="T_529b5_row12_col1" class="data row12 col1" >DEBUG</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_529b5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_529b5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_529b5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_529b5_row0_col0, #T_529b5_row0_col1, #T_529b5_row1_col0, #T_529b5_row1_col1, #T_529b5_row2_col0, #T_529b5_row2_col1, #T_529b5_row3_col0, #T_529b5_row3_col1, #T_529b5_row4_col0, #T_529b5_row4_col1, #T_529b5_row5_col0, #T_529b5_row5_col1, #T_529b5_row6_col0, #T_529b5_row6_col1, #T_529b5_row7_col0, #T_529b5_row7_col1, #T_529b5_row8_col0, #T_529b5_row8_col1, #T_529b5_row9_col0, #T_529b5_row9_col1, #T_529b5_row10_col0, #T_529b5_row10_col1, #T_529b5_row11_col0, #T_529b5_row11_col1, #T_529b5_row12_col0, #T_529b5_row12_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_529b5">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_529b5_row0_col0" class="data row0 col0" >credmgr_host</td>
#       <td id="T_529b5_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row1_col0" class="data row1 col0" >orchestrator_host</td>
#       <td id="T_529b5_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row2_col0" class="data row2 col0" >fabric_token</td>
#       <td id="T_529b5_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row3_col0" class="data row3 col0" >project_id</td>
#       <td id="T_529b5_row3_col1" class="data row3 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row4_col0" class="data row4 col0" >bastion_username</td>
#       <td id="T_529b5_row4_col1" class="data row4 col1" >pruth_0000000529</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row5_col0" class="data row5 col0" >bastion_key_filename</td>
#       <td id="T_529b5_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row6_col0" class="data row6 col0" >bastion_public_addr</td>
#       <td id="T_529b5_row6_col1" class="data row6 col1" >bastion-1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row7_col0" class="data row7 col0" >bastion_passphrase</td>
#       <td id="T_529b5_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row8_col0" class="data row8 col0" >slice_public_key_file</td>
#       <td id="T_529b5_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row9_col0" class="data row9 col0" >slice_private_key_file</td>
#       <td id="T_529b5_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row10_col0" class="data row10 col0" >fabric_slice_private_key_passphrase</td>
#       <td id="T_529b5_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row11_col0" class="data row11 col0" >fablib_log_file</td>
#       <td id="T_529b5_row11_col1" class="data row11 col1" >fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_529b5_row12_col0" class="data row12 col0" >fablib_log_level</td>
#       <td id="T_529b5_row12_col1" class="data row12 col1" >DEBUG</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Step 3 (Optional): Query for Available Testbed Resources and Settings
#
# This optional command queries the FABRIC services to find the available resources. It may be useful for finding a site with available capacity.

# %%
try:
    print(f"{fablib.list_sites()}")
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 4: Create the Experiment Slice
#
# The following creates a single node with basic compute capabilities. You build a slice by creating a new slice and adding resources to the slice. After you build the slice, you must submit a request for the slice to be instantiated.
#
# By default, the submit function will block until the node is ready and will display the progress of your slice being built.
#
#
# <img src="./figs/SingleNode.png" width="20%"><br>

# %%
try:
    # Create a slice
    slice = fablib.new_slice(name="MySlice3002")

    # Add a node
    for i in range(10):
        slice.add_node(name=f"rocky_node{i}", avoid=['GPN','FIU','CLEM','UCSD','STAR','MAX'], image='default_rocky_8')
    
    for i in range(10):
        slice.add_node(name=f"ubuntu_node{i}", avoid=['GPN','FIU','CLEM','UCSD','STAR','MAX', 'NCSA'], image='default_ubuntu_20')

    
    # Submit the slice
    slice.submit()
except Exception as e:
    print(f"Exception: {e}")
    raise e
# Out:
# Retry: 6, Time: 171 sec
# <style type="text/css">
# #T_392f8 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_392f8 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_392f8 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_392f8_row0_col0, #T_392f8_row0_col1, #T_392f8_row1_col0, #T_392f8_row1_col1, #T_392f8_row2_col0, #T_392f8_row2_col1, #T_392f8_row3_col0, #T_392f8_row3_col1, #T_392f8_row4_col0, #T_392f8_row4_col1, #T_392f8_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_392f8_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_392f8">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_392f8_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_392f8_row0_col1" class="data row0 col1" >450b81d8-6cdd-4448-b894-24b290ea07c0</td>
#     </tr>
#     <tr>
#       <td id="T_392f8_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_392f8_row1_col1" class="data row1 col1" >MySlice3002</td>
#     </tr>
#     <tr>
#       <td id="T_392f8_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_392f8_row2_col1" class="data row2 col1" >2022-10-24 15:39:33 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_392f8_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_392f8_row3_col1" class="data row3 col1" >2022-10-23 15:39:34 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_392f8_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_392f8_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_392f8_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_392f8_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_13f92 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_13f92 th {
#   text-align: left;
# }
# #T_13f92 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_13f92 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_13f92 .level0 {
#   border: 1px black solid !important;
# }
# #T_13f92_row0_col0, #T_13f92_row0_col1, #T_13f92_row0_col2, #T_13f92_row0_col3, #T_13f92_row0_col4, #T_13f92_row0_col5, #T_13f92_row0_col6, #T_13f92_row0_col7, #T_13f92_row0_col8, #T_13f92_row1_col0, #T_13f92_row1_col1, #T_13f92_row1_col2, #T_13f92_row1_col3, #T_13f92_row1_col4, #T_13f92_row1_col5, #T_13f92_row1_col6, #T_13f92_row1_col7, #T_13f92_row1_col8, #T_13f92_row2_col0, #T_13f92_row2_col1, #T_13f92_row2_col2, #T_13f92_row2_col3, #T_13f92_row2_col4, #T_13f92_row2_col5, #T_13f92_row2_col6, #T_13f92_row2_col7, #T_13f92_row2_col8, #T_13f92_row3_col0, #T_13f92_row3_col1, #T_13f92_row3_col2, #T_13f92_row3_col3, #T_13f92_row3_col4, #T_13f92_row3_col5, #T_13f92_row3_col6, #T_13f92_row3_col7, #T_13f92_row3_col8, #T_13f92_row4_col0, #T_13f92_row4_col1, #T_13f92_row4_col2, #T_13f92_row4_col3, #T_13f92_row4_col4, #T_13f92_row4_col5, #T_13f92_row4_col6, #T_13f92_row4_col7, #T_13f92_row4_col8, #T_13f92_row5_col0, #T_13f92_row5_col1, #T_13f92_row5_col2, #T_13f92_row5_col3, #T_13f92_row5_col4, #T_13f92_row5_col5, #T_13f92_row5_col6, #T_13f92_row5_col7, #T_13f92_row5_col8, #T_13f92_row6_col0, #T_13f92_row6_col1, #T_13f92_row6_col2, #T_13f92_row6_col3, #T_13f92_row6_col4, #T_13f92_row6_col5, #T_13f92_row6_col6, #T_13f92_row6_col7, #T_13f92_row6_col8, #T_13f92_row7_col0, #T_13f92_row7_col1, #T_13f92_row7_col2, #T_13f92_row7_col3, #T_13f92_row7_col4, #T_13f92_row7_col5, #T_13f92_row7_col6, #T_13f92_row7_col7, #T_13f92_row7_col8, #T_13f92_row8_col0, #T_13f92_row8_col1, #T_13f92_row8_col2, #T_13f92_row8_col3, #T_13f92_row8_col4, #T_13f92_row8_col5, #T_13f92_row8_col6, #T_13f92_row8_col7, #T_13f92_row8_col8, #T_13f92_row9_col0, #T_13f92_row9_col1, #T_13f92_row9_col2, #T_13f92_row9_col3, #T_13f92_row9_col4, #T_13f92_row9_col5, #T_13f92_row9_col6, #T_13f92_row9_col7, #T_13f92_row9_col8, #T_13f92_row10_col0, #T_13f92_row10_col1, #T_13f92_row10_col2, #T_13f92_row10_col3, #T_13f92_row10_col4, #T_13f92_row10_col5, #T_13f92_row10_col6, #T_13f92_row10_col7, #T_13f92_row10_col8, #T_13f92_row11_col0, #T_13f92_row11_col1, #T_13f92_row11_col2, #T_13f92_row11_col3, #T_13f92_row11_col4, #T_13f92_row11_col5, #T_13f92_row11_col6, #T_13f92_row11_col7, #T_13f92_row11_col8, #T_13f92_row12_col0, #T_13f92_row12_col1, #T_13f92_row12_col2, #T_13f92_row12_col3, #T_13f92_row12_col4, #T_13f92_row12_col5, #T_13f92_row12_col6, #T_13f92_row12_col7, #T_13f92_row12_col8, #T_13f92_row13_col0, #T_13f92_row13_col1, #T_13f92_row13_col2, #T_13f92_row13_col3, #T_13f92_row13_col4, #T_13f92_row13_col5, #T_13f92_row13_col6, #T_13f92_row13_col7, #T_13f92_row13_col8, #T_13f92_row14_col0, #T_13f92_row14_col1, #T_13f92_row14_col2, #T_13f92_row14_col3, #T_13f92_row14_col4, #T_13f92_row14_col5, #T_13f92_row14_col6, #T_13f92_row14_col7, #T_13f92_row14_col8, #T_13f92_row15_col0, #T_13f92_row15_col1, #T_13f92_row15_col2, #T_13f92_row15_col3, #T_13f92_row15_col4, #T_13f92_row15_col5, #T_13f92_row15_col6, #T_13f92_row15_col7, #T_13f92_row15_col8, #T_13f92_row16_col0, #T_13f92_row16_col1, #T_13f92_row16_col2, #T_13f92_row16_col3, #T_13f92_row16_col4, #T_13f92_row16_col5, #T_13f92_row16_col6, #T_13f92_row16_col7, #T_13f92_row16_col8, #T_13f92_row17_col0, #T_13f92_row17_col1, #T_13f92_row17_col2, #T_13f92_row17_col3, #T_13f92_row17_col4, #T_13f92_row17_col5, #T_13f92_row17_col6, #T_13f92_row17_col7, #T_13f92_row17_col8, #T_13f92_row18_col0, #T_13f92_row18_col1, #T_13f92_row18_col2, #T_13f92_row18_col3, #T_13f92_row18_col4, #T_13f92_row18_col5, #T_13f92_row18_col6, #T_13f92_row18_col7, #T_13f92_row18_col8, #T_13f92_row19_col0, #T_13f92_row19_col1, #T_13f92_row19_col2, #T_13f92_row19_col3, #T_13f92_row19_col4, #T_13f92_row19_col5, #T_13f92_row19_col6, #T_13f92_row19_col7, #T_13f92_row19_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_13f92_row0_col9, #T_13f92_row1_col9, #T_13f92_row2_col9, #T_13f92_row3_col9, #T_13f92_row4_col9, #T_13f92_row5_col9, #T_13f92_row6_col9, #T_13f92_row7_col9, #T_13f92_row8_col9, #T_13f92_row9_col9, #T_13f92_row10_col9, #T_13f92_row11_col9, #T_13f92_row12_col9, #T_13f92_row13_col9, #T_13f92_row14_col9, #T_13f92_row15_col9, #T_13f92_row16_col9, #T_13f92_row17_col9, #T_13f92_row18_col9, #T_13f92_row19_col9 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_13f92_row0_col10, #T_13f92_row1_col10, #T_13f92_row2_col10, #T_13f92_row3_col10, #T_13f92_row4_col10, #T_13f92_row5_col10, #T_13f92_row6_col10, #T_13f92_row7_col10, #T_13f92_row8_col10, #T_13f92_row9_col10, #T_13f92_row10_col10, #T_13f92_row11_col10, #T_13f92_row12_col10, #T_13f92_row13_col10, #T_13f92_row14_col10, #T_13f92_row15_col10, #T_13f92_row16_col10, #T_13f92_row17_col10, #T_13f92_row18_col10, #T_13f92_row19_col10 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_13f92">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_13f92_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_13f92_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_13f92_level0_col2" class="col_heading level0 col2" >Site</th>
#       <th id="T_13f92_level0_col3" class="col_heading level0 col3" >Host</th>
#       <th id="T_13f92_level0_col4" class="col_heading level0 col4" >Cores</th>
#       <th id="T_13f92_level0_col5" class="col_heading level0 col5" >RAM</th>
#       <th id="T_13f92_level0_col6" class="col_heading level0 col6" >Disk</th>
#       <th id="T_13f92_level0_col7" class="col_heading level0 col7" >Image</th>
#       <th id="T_13f92_level0_col8" class="col_heading level0 col8" >Management IP</th>
#       <th id="T_13f92_level0_col9" class="col_heading level0 col9" >State</th>
#       <th id="T_13f92_level0_col10" class="col_heading level0 col10" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_13f92_row0_col0" class="data row0 col0" >2e9580f4-706b-4896-a85b-f5f4a8dbd778</td>
#       <td id="T_13f92_row0_col1" class="data row0 col1" >rocky_node0</td>
#       <td id="T_13f92_row0_col2" class="data row0 col2" >MASS</td>
#       <td id="T_13f92_row0_col3" class="data row0 col3" >mass-w3.fabric-testbed.net</td>
#       <td id="T_13f92_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_13f92_row0_col5" class="data row0 col5" >8</td>
#       <td id="T_13f92_row0_col6" class="data row0 col6" >10</td>
#       <td id="T_13f92_row0_col7" class="data row0 col7" >default_rocky_8</td>
#       <td id="T_13f92_row0_col8" class="data row0 col8" >205.172.170.73</td>
#       <td id="T_13f92_row0_col9" class="data row0 col9" >Active</td>
#       <td id="T_13f92_row0_col10" class="data row0 col10" ></td>
#     </tr>
#     <tr>
#       <td id="T_13f92_row1_col0" class="data row1 col0" >aaab3741-a428-4429-89fc-53d7b6afc73c</td>
#       <td id="T_13f92_row1_col1" class="data row1 col1" >rocky_node1</td>
#       <td id="T_13f92_row1_col2" class="data row1 col2" >MASS</td>
#       <td id="T_13f92_row1_col3" class="data row1 col3" >mass-w3.fabric-testbed.net</td>
#       <td id="T_13f92_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_13f92_row1_col5" class="data row1 col5" >8</td>
#       <td id="T_13f92_row1_col6" class="data row1 col6" >10</td>
#       <td id="T_13f92_row1_col7" class="data row1 col7" >default_rocky_8</td>
#       <td id="T_13f92_row1_col8" class="data row1 col8" >205.172.170.125</td>
#       <td id="T_13f92_row1_col9" class="data row1 col9" >Active</td>
#       <td id="T_13f92_row1_col10" class="data row1 col10" ></td>
#     </tr>
#     <tr>
#       <td id="T_13f92_row2_col0" class="data row2 col0" >edbe739f-104b-4f16-a1bb-b4c9f13d5bda</td>
#       <td id="T_13f92_row2_col1" class="data row2 col1" >rocky_node2</td>
# Time to stable 171 seconds
# Running post_boot_config ... Time to post boot config 211 seconds

# %% [markdown]
# ## Step 5: Observe the Slice's Attributes

# %%
file = open("ansible_hosts", "w") 
file.write("[nodes] \n")
for node in slice.get_nodes():
    file.write(f"{node.get_name()} ansible_host={node.get_management_ip()} ansible_user={node.get_username()} ansible_port=22 ansible_ssh_private_key_file={node.get_private_key_file()} \n")
file.close()

# %%
# !time ansible-playbook -f 10 -i ansible_hosts playbook.yaml
# Out:
# PLAY [Intro to Ansible Playbooks] **********************************************
#
# TASK [Gathering Facts] *********************************************************
# ok: [rocky_node5]
# ok: [rocky_node4]
# ok: [rocky_node0]
# ok: [rocky_node1]
# ok: [rocky_node8]
# ok: [rocky_node7]
# ok: [rocky_node6]
# ok: [rocky_node2]
# ok: [rocky_node3]
# ok: [rocky_node9]
# ok: [ubuntu_node1]
# ok: [ubuntu_node0]
# ok: [ubuntu_node4]
# ok: [ubuntu_node2]
# ok: [ubuntu_node6]
# ok: [ubuntu_node8]
# ok: [ubuntu_node3]
# ok: [ubuntu_node7]
#
# TASK [Copy file] ***************************************************************
# ok: [rocky_node0]
# ok: [rocky_node1]
# ok: [rocky_node4]
# ok: [rocky_node5]
# ok: [rocky_node2]
# ok: [rocky_node3]
# ok: [rocky_node6]
# ok: [rocky_node7]
# ok: [rocky_node8]
# ok: [rocky_node9]
# ok: [ubuntu_node0]
# ok: [ubuntu_node1]
# ok: [ubuntu_node2]
#
# TASK [Copy dir] ****************************************************************
# ok: [rocky_node5]
#
# TASK [Copy file] ***************************************************************
# ok: [ubuntu_node4]
# ok: [ubuntu_node6]
#
# TASK [Copy dir] ****************************************************************
# ok: [rocky_node0]
# ok: [rocky_node1]
#
# TASK [Copy file] ***************************************************************
# ok: [ubuntu_node3]
#
# TASK [Copy dir] ****************************************************************
# ok: [rocky_node4]
#
# TASK [Gathering Facts] *********************************************************
# ok: [ubuntu_node9]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node5]
#
# TASK [Copy file] ***************************************************************
# ok: [ubuntu_node7]
# ok: [ubuntu_node8]
#
# TASK [Gathering Facts] *********************************************************
# ok: [ubuntu_node5]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node0]
#
# TASK [Copy dir] ****************************************************************
# ok: [rocky_node2]
# ok: [rocky_node3]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node5]
#
# TASK [Copy dir] ****************************************************************
# ok: [rocky_node6]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node1]
#
# TASK [Copy dir] ****************************************************************
# ok: [rocky_node7]
# ok: [rocky_node8]
# ok: [ubuntu_node1]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node0]
# skipping: [rocky_node1]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node4]
#
# TASK [Copy dir] ****************************************************************
# ok: [ubuntu_node0]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node2]
#
# TASK [Copy dir] ****************************************************************
# ok: [ubuntu_node2]
# ok: [rocky_node9]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node3]
#
# TASK [Install RedHat Packages] *************************************************
# ok: [rocky_node5]
# ok: [rocky_node0]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node6]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node2]
# skipping: [rocky_node3]
# skipping: [rocky_node4]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node7]
# skipping: [ubuntu_node0]
# skipping: [ubuntu_node1]
# ok: [rocky_node8]
# skipping: [ubuntu_node2]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node0]
#
# TASK [Install RedHat Packages] *************************************************
# ok: [rocky_node1]
#
# TASK [Copy dir] ****************************************************************
# ok: [ubuntu_node4]
#
# TASK [Install RedHat Packages] *************************************************
# ok: [rocky_node2]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node5]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node6]
# skipping: [rocky_node7]
# skipping: [rocky_node8]
# skipping: [ubuntu_node0]
# skipping: [ubuntu_node1]
#
# TASK [Copy dir] ****************************************************************
# ok: [ubuntu_node6]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node2]
#
# TASK [Install Ubuntu packages] *************************************************
# skipping: [rocky_node0]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node1]
# skipping: [rocky_node2]
#
# TASK [Install Ubuntu packages] *************************************************
# skipping: [rocky_node5]
#
# TASK [Install RedHat epel] *****************************************************
# ok: [rocky_node9]
#
# TASK [Copy dir] ****************************************************************
# ok: [ubuntu_node8]
#
# TASK [Install RedHat Packages] *************************************************
# skipping: [ubuntu_node0]
# skipping: [ubuntu_node1]
#
# TASK [Install RedHat epel] *****************************************************
# skipping: [ubuntu_node4]
#
# TASK [Install RedHat Packages] *************************************************
# ok: [rocky_node4]
#
# TASK [Install Ubuntu packages] *************************************************
# skipping: [rocky_node1]
# skipping: [rocky_node2]
#
# TASK [Install RedHat Packages] *************************************************
# ok: [rocky_node3]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node9]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node0]
# skipping: [ubuntu_node1]
#
# TASK [Install RedHat Packages] *************************************************
# skipping: [ubuntu_node2]
#
# TASK [Install RedHat epel] *****************************************************
# skipping: [ubuntu_node6]
# skipping: [ubuntu_node8]
#
# TASK [Copy dir] ****************************************************************
# ok: [ubuntu_node3]
# ok: [ubuntu_node7]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node3]
# skipping: [rocky_node4]
#
# TASK [Install RedHat Packages] *************************************************
# ok: [rocky_node6]
# ok: [rocky_node7]
# ok: [rocky_node8]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node2]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node4]
# skipping: [ubuntu_node6]
#
# TASK [Install Ubuntu packages] *************************************************
# skipping: [rocky_node3]
#
# TASK [command2] ****************************************************************
# ok: [rocky_node5]
#
# TASK [Install Ubuntu packages] *************************************************
# skipping: [rocky_node4]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node6]
# skipping: [rocky_node7]
# skipping: [rocky_node8]
#
# TASK [command2] ****************************************************************
# ok: [rocky_node0]
#
# TASK [Install RedHat epel] *****************************************************
# skipping: [ubuntu_node3]
#
# TASK [Install RedHat Packages] *************************************************
# skipping: [ubuntu_node4]
#
# TASK [Install RedHat epel] *****************************************************
# skipping: [ubuntu_node7]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node8]
#
# TASK [command2] ****************************************************************
# ok: [rocky_node1]
#
# TASK [Install Ubuntu packages] *************************************************
# skipping: [rocky_node6]
# skipping: [rocky_node7]
# skipping: [rocky_node8]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node3]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node4]
#
# TASK [Install RedHat Packages] *************************************************
# skipping: [ubuntu_node6]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node7]
#
# TASK [command2] ****************************************************************
# ok: [rocky_node2]
# ok: [rocky_node4]
# ok: [rocky_node3]
#
# TASK [Install RedHat Packages] *************************************************
# skipping: [ubuntu_node3]
#
# TASK [command2] ****************************************************************
# ok: [rocky_node6]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node6]
#
# TASK [Install RedHat Packages] *************************************************
# skipping: [ubuntu_node8]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node3]
#
# TASK [Install RedHat Packages] *************************************************
# ok: [rocky_node9]
# skipping: [ubuntu_node7]
#
# TASK [Copy file] ***************************************************************
# fatal: [ubuntu_node9]: FAILED! => {"msg": "Timeout (12s) waiting for privilege escalation prompt: "}
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [rocky_node9]
# skipping: [ubuntu_node8]
#
# TASK [Install Ubuntu packages] *************************************************
# skipping: [rocky_node9]
#
# TASK [Enable EPEL Repository on CentOS 7] **************************************
# skipping: [ubuntu_node7]
#
# TASK [command2] ****************************************************************
# ok: [rocky_node7]
#
# TASK [Install Ubuntu packages] *************************************************
# ok: [ubuntu_node0]
# ok: [ubuntu_node1]
# ok: [ubuntu_node2]
#
# TASK [command2] ****************************************************************
# ok: [rocky_node8]
# ok: [ubuntu_node0]
# ok: [ubuntu_node1]
#
# TASK [Install Ubuntu packages] *************************************************
# ok: [ubuntu_node4]
#
# TASK [Copy file] ***************************************************************
# fatal: [ubuntu_node5]: FAILED! => {"msg": "Timeout (12s) waiting for privilege escalation prompt: "}
#
# TASK [command2] ****************************************************************
# ok: [rocky_node9]
#
# TASK [Install Ubuntu packages] *************************************************
# ok: [ubuntu_node6]
#
# TASK [command2] ****************************************************************
# ok: [ubuntu_node2]
#
# TASK [Install Ubuntu packages] *************************************************
# ok: [ubuntu_node8]
# ok: [ubuntu_node3]
# ok: [ubuntu_node7]
#
# TASK [command2] ****************************************************************
# ok: [ubuntu_node4]
# ok: [ubuntu_node6]
# ok: [ubuntu_node8]
# ok: [ubuntu_node3]
# ok: [ubuntu_node7]
#
# PLAY RECAP *********************************************************************
# rocky_node0                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node1                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node2                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node3                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node4                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node5                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node6                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node7                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node8                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# rocky_node9                : ok=6    changed=0    unreachable=0    failed=0    skipped=3    rescued=0    ignored=0
# ubuntu_node0               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node1               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node2               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node3               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node4               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node5               : ok=1    changed=0    unreachable=0    failed=1    skipped=0    rescued=0    ignored=0
# ubuntu_node6               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node7               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node8               : ok=5    changed=0    unreachable=0    failed=0    skipped=4    rescued=0    ignored=0
# ubuntu_node9               : ok=1    changed=0    unreachable=0    failed=1    skipped=0    rescued=0    ignored=0
#
#
# real	1m3.547s
# user	0m30.703s
# sys	0m21.901s

# %%
slice = fablib.get_slice(name="MySlice1")
slice.list_nodes(output='jupyter')

# %% [markdown]
# ### Print the node
#
# Each node in the slice has a set of get functions that return the node's attributes.

# %%
try:
    for node in slice.get_nodes():
        #print(f"{node}")
        node.show()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 6: Run the Experiment
#
# Most experiments will require automated configuration and execution. You can use the fablib library to execute arbitrary commands on your node.
#
# The following code demonstrates how to use fablib to execute a "Hello, FABRIC" bash script. The library uses the bastion and VM keys defined at the top of this notebook to jump through the bastion host and execute the script.

# %%
try:
    for node in slice.get_nodes():
        node.execute('echo Hello, FABRIC from node `hostname -s`', output='live')
        #print(stdout)
        
        node.execute('sudo yum install -y net-tools pciutils', output='live')
        

except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## Step 7: Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
