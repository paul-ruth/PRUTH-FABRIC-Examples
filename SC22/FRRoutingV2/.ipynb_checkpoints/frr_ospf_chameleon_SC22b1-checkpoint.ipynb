# %% [markdown]
# # Routing Topology: OSPF using FRRouting with Chameleon
#
# This notebook is an example of how to create a FABRIC routing experiment topology comprising nodes at three different sites. Each site has a local layer 2 (Ethernet) network connecting a set of local nodes and one gateway router. The three gateway routers connect to each other and use the [FRRouting](https://frrouting.org/) protocol suite to deploy [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) dameons to propagate route updates across the topology.
#
# You might be familiar with the [Quagga](https://www.quagga.net/) router suite.  FRRouting is based on Quagga but has a more active upstream community including many large companies working on cloud networking.
#
#
# ## Configure the Environment

# %%
import os
import sys

module_path = os.path.abspath(os.path.join(f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fablib_local"))
if module_path not in sys.path:
    sys.path.append(module_path)
from fablib_custom.fablib_custom import *

from chameleon_utils.chameleon_config import *

load_chameleon_rc_environment(chameleon_rc_file=f"{os.environ['HOME']}/work/fablib_local_private_config/Chameleon-openrc.sh")

from my_experiment.frrouting_experiment import FRRouting_Experiment

# %% [markdown]
# ## Create the Experiment

# %%
frr_experiment = FRRouting_Experiment('FRRouting_OSPF_SC22')

# %% [markdown]
# ## (Optional): Query for Available Tesbed Resources and Settings

# %%
try:
    frr_experiment.list_sites()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_b27c3 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b27c3 th {
#   text-align: left;
# }
# #T_b27c3 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b27c3 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b27c3 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b27c3_row0_col0, #T_b27c3_row0_col1, #T_b27c3_row0_col2, #T_b27c3_row0_col3, #T_b27c3_row0_col4, #T_b27c3_row0_col5, #T_b27c3_row0_col6, #T_b27c3_row0_col7, #T_b27c3_row0_col8, #T_b27c3_row0_col9, #T_b27c3_row0_col10, #T_b27c3_row0_col11, #T_b27c3_row0_col12, #T_b27c3_row0_col13, #T_b27c3_row0_col14, #T_b27c3_row0_col15, #T_b27c3_row0_col16, #T_b27c3_row0_col17, #T_b27c3_row0_col18, #T_b27c3_row0_col19, #T_b27c3_row0_col20, #T_b27c3_row0_col21, #T_b27c3_row0_col22, #T_b27c3_row0_col23, #T_b27c3_row0_col24, #T_b27c3_row0_col25, #T_b27c3_row0_col26, #T_b27c3_row0_col27, #T_b27c3_row0_col28, #T_b27c3_row0_col29, #T_b27c3_row0_col30, #T_b27c3_row0_col31, #T_b27c3_row1_col0, #T_b27c3_row1_col1, #T_b27c3_row1_col2, #T_b27c3_row1_col3, #T_b27c3_row1_col4, #T_b27c3_row1_col5, #T_b27c3_row1_col6, #T_b27c3_row1_col7, #T_b27c3_row1_col8, #T_b27c3_row1_col9, #T_b27c3_row1_col10, #T_b27c3_row1_col11, #T_b27c3_row1_col12, #T_b27c3_row1_col13, #T_b27c3_row1_col14, #T_b27c3_row1_col15, #T_b27c3_row1_col16, #T_b27c3_row1_col17, #T_b27c3_row1_col18, #T_b27c3_row1_col19, #T_b27c3_row1_col20, #T_b27c3_row1_col21, #T_b27c3_row1_col22, #T_b27c3_row1_col23, #T_b27c3_row1_col24, #T_b27c3_row1_col25, #T_b27c3_row1_col26, #T_b27c3
_row5_col6, #T_b27c3_row5_col7, #T_b27c3_row5_col8, #T_b27c3_row5_col9, #T_b27c3_row5_col10, #T_b27c3_row5_col11, #T_b27c3_row5_col12, #T_b27c3_row5_col13, #T_b27c3_row5_col14, #T_b27c3_row5_col15, #T_b27c3_row5_col16, #T_b27c3_row5_col17, #T_b27c3_row5_col18, #T_b27c3_row5_col19, #T_b27c3_row5_col20, #T_b27c3_row5_col21, #T_b27c3_row5_col22, #T_b27c3_row5_col23, #T_b27c3_row5_col24, #T_b27c3_row5_col25, #T_b27c3_row5_col26, #T_b27c3_row5_col27, #T_b27c3_row5_col28, #T_b27c3_row5_col29, #T_b27c3_row5_col30, #T_b27c3_row5_col31, #T_b27c3_row6_col0, #T_b27c3 ...

# %% [markdown]
# ## Define Experiment
#
# The following creates private layer 2 networks on three sites including a OSPF gateway routers that propogate routes acrross the topology.

# %%
frr_sites = { 'cham': { 'site': 'STAR', 'facility': 'CHI@UC', 'node_count': 2 },
              'mich': { 'site': 'MICH', 'facility': 'FABRIC', 'node_count': 1 },
            }
    
frr_links = { 'Link12': ('cham','mich'),
            }

# %%
frr_sites = { 'dall': { 'site': 'DALL', 'facility': 'FABRIC', 'node_count': 1},
              'salt': { 'site': 'SALT', 'facility': 'FABRIC', 'node_count': 1 },
              ##'cham': { 'site': 'STAR', 'facility': 'CHI@UC', 'node_count': 2 },
              'wash': { 'site': 'WASH', 'facility': 'FABRIC', 'node_count': 1 },
              'utah': { 'site': 'UTAH', 'facility': 'FABRIC', 'node_count': 1 }
            }
    
frr_links = { 'Link12': ('dall','salt'),
              'Link23': ('salt','wash'),
              'Link31': ('wash','dall'),
              'Link24': ('utah','salt')
            }

# %%
frr_experiment.configure(frr_sites, frr_links)

# %%
frr_experiment.deploy()
# Out:
# Retry: 4, Time: 466 sec
# <style type="text/css">
# #T_9d609 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9d609 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9d609 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_9d609_row0_col0, #T_9d609_row0_col1, #T_9d609_row1_col0, #T_9d609_row1_col1, #T_9d609_row2_col0, #T_9d609_row2_col1, #T_9d609_row3_col0, #T_9d609_row3_col1, #T_9d609_row4_col0, #T_9d609_row4_col1, #T_9d609_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_9d609_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_9d609">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9d609_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_9d609_row0_col1" class="data row0 col1" >bb4a46f4-4dc9-4252-852d-4a9a65376e1d</td>
#     </tr>
#     <tr>
#       <td id="T_9d609_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_9d609_row1_col1" class="data row1 col1" >FRRouting_OSPF_SC22</td>
#     </tr>
#     <tr>
#       <td id="T_9d609_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_9d609_row2_col1" class="data row2 col1" >2022-11-09 15:26:57 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9d609_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_9d609_row3_col1" class="data row3 col1" >2022-11-08 15:26:58 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9d609_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_9d609_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_9d609_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_9d609_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0504a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0504a th {
#   text-align: left;
# }
# #T_0504a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0504a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0504a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_
col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_0504a">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_0504a_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0504a_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0504a_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_0504a_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_0504a_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_0504a_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_0504a_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_0504a_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_0504a_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_0504a_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_0504a_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_0504a_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_0504a_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_0504a_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_0504a_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_0504a_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0504a_row0_col0" class="data row0 col0" >241a4956-a424-4bb7-a7a8-2bd18cfe9712</td>
#       <td id="T_0504a_row0_col1" class="data row0 col1" >router_dall</td>
#       <td id="T_0504a_row0_col2" class="data row0 col2" >32</td>
#       <td id="T_0504a_row0_col3" class="data row0 col3" >128</td>
#       <td id="T_0504a_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_0504a_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_0504a_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_0504a_row0_col7" class="data row0 col7" >dall-w3.fabric-testbed.net</td>
#       <td id="T_0504a_row0_col8" class="data row0 col8" >DALL</td>
#       <td id="T_0504a_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_0504a_row0_col10" class="data row0 col10" >2001:400:a100:3000:f816:3eff:fe83:8ea5</td>
#       <td id="T_0504a_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_0504a_row0_col12" class="data row0 col12" ></td>
#       <td id="T_0504a_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fe83:8ea5</td>
#       <td id="T_0504a_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0504a_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0504a_row1_col0" class="data row1 col0" >ecc63d6e-bf8e-42f0-be4d-c7dcdae802f6</td>
#       <td id="T_0504a_row1_col1" class="data row1 col1" >router_salt</td>
#       <td id="T_0504a_row1_col2" class="data row1 col2" >32</td>
#       <td id="T_0504a_row1_col3" class="data row1 col3" >128</td>
#       <td id="T_0504a_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_0504a_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_0504a_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_0504a_row1_col7" class="data row1 col7" >salt-w2.fabric-testbed.net</td>
#       <td id="T_0504a_row1_col8" class="data row1 col8" >SALT</td>
#       <td id="T_0504a_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_0504a_row1_col10" class="data row1 col10" >2001:400:a100:3010:f816:3eff:fe83:c8b5</td>
#       <td id="T_0504a_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_0504a_row1_col12" class="data row1 col12" ></td>
#       <td id="T_0504a_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3010:f816:3eff:fe83:c8b5</td>
#       <td id="T_0504a_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0504a_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0504a_row2_col0" class="data row2 col0" >b76f78db-d7c6-442a-acf7-82c2422e7a84</td>
#       <td id="T_0504a_row2_col1" class="data row2 col1" >router_wash</td>
#       <td id="T_0504a_row2_col2" class="data row2 col2" >32</td>
#       <td id="T_0504a_row2_col3" class="data row2 col3" >128</td>
#       <td id="T_0504a_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_0504a_row2_col5" class="data row2 col5" >default_ro
# <style type="text/css">
# #T_99c66 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_99c66 th {
#   text-align: left;
# }
# #T_99c66 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_99c66 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_99c66 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_99c66_row0_col0, #T_99c66_row0_col1, #T_99c66_row0_col2, #T_99c66_row0_col3, #T_99c66_row0_col4, #T_99c66_row0_col5, #T_99c66_row0_col6, #T_99c66_row1_col0, #T_99c66_row1_col1, #T_99c66_row1_col2, #T_99c66_row1_col3, #T_99c66_row1_col4, #T_99c66_row1_col5, #T_99c66_row1_col6, #T_99c66_row2_col0, #T_99c66_row2_col1, #T_99c66_row2_col2, #T_99c66_row2_col3, #T_99c66_row2_col4, #T_99c66_row2_col5, #T_99c66_row2_col6, #T_99c66_row3_col0, #T_99c66_row3_col1, #T_99c66_row3_col2, #T_99c66_row3_col3, #T_99c66_row3_col4, #T_99c66_row
row4_col5" class="data row4 col5" >None</td>
#       <td id="T_99c66_row4_col6" class="data row4 col6" >None</td>
#       <td id="T_99c66_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_99c66_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c66_row5_col0" class="data row5 col0" >e82e7e56-3744-483a-91b5-1a17d89e2d2f</td>
#       <td id="T_99c66_row5_col1" class="data row5 col1" >salt</td>
#       <td id="T_99c66_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_99c66_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_99c66_row5_col4" class="data row5 col4" >SALT</td>
#       <td id="T_99c66_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_99c66_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_99c66_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_99c66_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c66_row6_col0" class="data row6 col0" >588c9af2-799d-42a3-9f71-4081463eb3b8</td>
#       <td id="T_99c66_row6_col1" class="data row6 col1" >wash</td>
#       <td id="T_99c66_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_99c66_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_99c66_row6_col4" class="data row6 col4" >WASH</td>
#       <td id="T_99c66_row6_col5" class="data row6 col5" >None</td>
#       <td id="T_99c66_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_99c66_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_99c66_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_99c66_row7_col0" class="data row7 col0" >57ac5ca3-0408-4b63-a60f-7c1615fe8589</td>
#       <td id="T_99c66_row7_col1" class="data row7 col1" >utah</td>
#       <td id="T_99c66_row7_col2" class="data row7 col2" >L2</td>
#       <td id="T_99c66_row7_col3" class="data row7 col3" >L2Bridge</td>
#       <td id="T_99c66_row7_col4" class="data row7 col4" >UTAH</td>
#       <td id="T_99c66_row7_col5" class="data row7 col5" >None</td>
#       <td id="T_99c66_row7_col6" cl
# Time to stable 466 seconds
# Running post_boot_config ... Time to post boot config 483 seconds
# <style type="text/css">
# #T_9ead9 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_9ead9 th {
#   text-align: left;
# }
# #T_9ead9 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9ead9 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9ead9 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9ead9_row0_col0, #T_9ead9_row0_col1, #T_9ead9_row0_col2, #T_9ead9_row0_col3, #T_9ead9_row0_col4, #T_9ead9_row0_col5, #T_9ead9_row0_col6, #T_9ead9_row0_col7, #T_9ead9_row1_col0, #T_9ead9_row1_col1, #T_9ead9_row1_col2, #T_9ead9_row1_col3, #T_9ead9_row1_col4, #T_9ead9_row1_col5, #T_9ead9_row1_col6, #T_9ead9_row1_col7, #T_9ead9_row2_col0, #T_9ead9_row2_col1, #T_9ead9_row2_col2, #T_9ead9_row2_col3, #T_9ead9_row2_col4, #T_9ead9_row2_col5, #T_9ead9_row2_col6, #T_9ead9_row2_col7, #T_9ead9_row3_col0, #T_9ead9_row3_col1, #T_9ead9_row3_col2, #T_9ead9_row3_col3, #T_9ead9_row3_col4, #T_9ead9_row3_col5, #T_9ead9_row3_col6, #T_9ead9_row3_col7, #T_9ead9_row4_col0, #T_9ead9_row4_col1, #T_9ead9_row4_col2, #T_9ead9_row4_col3, #T_9ead9_row4_col4, #T_9ead9_row4_col5, #T_9ead9_row4_col6, #T_9ead9_row4_col7, #T_9ead9_row5_col0, #T_9ead9_row5_col1, #T_9ead9_row5_col2, #T_9ead9_row5_col3, #T_9ead9_row5_col4, #T_9ead9_row5_col5, #T_9ead9_row5_col6, #T_9ead9_row5_col7, #T_9ead9_row6_col0, #T_9ead9_row6_col1, #T_9ead9_row6_col2, #T_9ead9_row6_col3, #T_9ead9_row6_col4, #T_9ead9_row6_col5, #T_9ead9_row6_col6, #T_9ead9_row6_col7, #T_9ead9_row7_col0, #T_9ead9_row7_col1, #T_9ead9_row7_col2, #T_9ead9_row7_col3, #T_9ead9_row7_col4, #T_9ead9_row7_col5, #T_9ead9_row7_col6, #T_9ead9_row7_col7, #T_9ead9_row8_col0, #T_9ead9_row8_col1, #T_9ead9_row8_col2, #T_9ead9_row8_col3, #T_9ead9_row8_col4, #T_9ead9_row8_col5, #T_9ead9_row8_col6, #T_9ead9_row8_col7, #T_9ead9_row9_col0, #T_9ead9_row9_col1, #T_9ead9_row9_col2, #T_9ead9_row9_col3, #T_9ead9_row9_col4, #T_9ead9_row9_col5, #T_9ead9_row9_col6, #T_9ead9_row9_col7, #T_9ead9_row10_col0, #T_9ead9_row10_col1, #T_9ead9_row10_col2, #T_9ead9_row10_col3, #T_9ead9_row10_col4, #T_9ead9_row10_col5, #T_9ead9_row10_col6, #T_9ead9_row10_col7, #T_9ead9_row11_col0, #T_9ead9_row11_col1, #T_9ead9_row11_col2, #T_9ead9_row11_col3, #T_9ead9_row11_col4, #T_9ead9_row11_col5, #T_9ead9_row11_col6, #T_9ead9_row11_col7, #T_9ead9_row12_col0, #T_9ead9_row12_col1, #T_9ead9_row12_col2, #T_9ead9_row12_col3, #T_9ead9_row12_col4, #T_9ead9_row12_col5, #T_9ead9_row12_col6, #T_9ead9_row12_col7, #T_9ead9_row13_col0, #T_9ead9_row13_col1, #T_9ead9_row13_col2, #T_9ead9_row13_col3, #T_9ead9_row13_col4, #T_9ead9_row13_col5, #T_9ead9_row13_col6, #T_9ead9_row13_col7, #T_9ead9_row14_col0, #T_9ead9_row14_col1, #T_9ead9_row14_col2, #T_9ead9_row14_col3, #T_9ead9_row14_col4, #T_9ead9_row14_col5, #T_9ead9_row14_col6, #T_9ead9_row14_col7, #T_9ead9_row15_col0, #T_9ead9_row15_col1, #T_9ead9_row15_col2, #T_9ead9_row15_col3, #T_9ead9_row15_col4, #T_9ead9_row15_col5, #T_9ead9_row15_col6, #T_9ead9_row15_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_9ead9">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_9ead9_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_9ead9_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_9ead9_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_9ead9_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_9ead9_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_9ead9_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_9ead9_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_9ead9_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9ead9_row0_col0" class="data row0 col0" >router_dall-Link31-p1</td>
#       <td id="T_9ead9_row0_col1" class="data row0 col1" >router_dall</td>
#       <td id="T_9ead9_row0_col2" class="data row0 col2" >Link31</td>
#       <td id="T_9ead9_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_9ead9_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_9ead9_row0_col5" class="data row0 col5" >06:A5:E9:90:73:2D</td>
#       <td id="T_9ead9_row0_col6" class="data row0 col6" >eth2</td>
#       <td id="T_9ead9_row0_col7" class="data row0 col7" >eth2</td>
#     </tr>
#     <tr>
#       <td id="T_9ead9_row1_col0" class="data row1 col0" >router_dall-dall-p1</td>
#       <td id="T_9ead9_row1_col1" class="data row1 col1" >router_dall</td>
#       <td id="T_9ead9_row1_col2" class="data row1 col2" >dall</td>
#       <td id="T_9ead9_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_9ead9_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_9ead9_row1_col5" class="data row1 col5" >02:21:DB:24:98:74</td>
#       <td id="T_9ead9_row1_col6" class="data row1 col6" >eth1</td>
#       <td id="T_9ead9_row1_col7" class="data row1 col7" >eth1</td>
#     </tr>
#     <tr>
#       <td id="T_9ead9_row2_col0" class="data row2 col0" >router_dall-Link12-p1</td>
#       <td id="T_9ead9_row2_col1" class="data row2 col1" >router_dall</td>
#       <td id="T_9ead9_row2_col2" class="data row2 col2" >Link12</td>
#       <td id="T_9ead9_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_9ead9_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_9ead9_row2_col5" class="data row2 col5" >0A:E9:54:EE:5A:01</td>
#       <td id="T_9ead9_row2_col6" class="data row2 col6" >eth3</td>
#       <td id="T_9ead9_row2_col7" class="data row2 col7" >eth3</td>
#     </tr>
#     <tr>
#       <td id="T_9ead9_row3_col0" class="data row3 col0" >router_salt-Link23-p1</td>
#       <td id="T_9ead9_row3_col1" class="data row3 col1" >router_salt</td>
#       <td id="T_9ead9_row3_col2" class="data row3 col2" >Link23</td>
#       <td id="T_9ead9_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_9ead9_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_9ead9_row3_col5" class="data row3 col5" >02:DC:32:2C:80:0B</td>
#       <td id="T_9ead9_row3_col6" class="data row3 col6" >eth2</td>
#       <td id="T_9ead9_row3_col7" class="data row3 col7" >eth2</td>
#     </tr>
#     <tr>
#       <td id="T_9ead9_row4_col0" class="data row4 col0" >router_salt-Link12-p1</td>
#       <td id="T_9ead9_row4_col1" class="data row4 col1" >router_salt</td>
#       <td id="T_9ead9_row4_col2" class="data row4 col2" >Link12</td>
#       <td id="T_9ead9_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_9ead9_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_9ead9_row4_col5" class="data row4 col5" >06:47:97:1A:82:F3</td>
#       <td id="T_9ead9_row4_col6" class="data row4 col6" >eth3</td>
#       <td id="T_9ead9_row4_col7" class="data row4 col7" >eth3</td>
#     </tr>
#     <tr>
#       <td id="T_9ead9_row5_col0" class="data row5 col0" >router_salt-Link24-p1</td>
#       <td id="T_9ead9_row5_col1" class="data row5 col1" >router_salt</td>
#       <td id="T_9ead9_row5_col2" class="data row5 col2" >Link24</td>
#       <td id="T_9ead9_row5_col3" class="data row5 col3" >100</td>
#       <td id="T_9ead9_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_9ead9_row5_col5" class="data row5 col5" >02:4E:4A:E1:D9:B5</td>
#       <td id="T_9ead9_row5_col6" class="data row5 col6" >eth1</td>
#       <td id="T_9ead9_row5_col7" class="data row5 col7" >eth1</td>
#     </tr>
#     <tr>
#       <td id="T_9ead9_row6_col0" class="data row6 col0" >router_salt-salt-p1</td>
#       <td id="T_9ead9_row6_col1" class="data row6 col1" >router_salt</td>
#       <td id="T_9ead9_row6_col2" class="data row6 col2" >salt</td>
#       <td id="T_9ead9_row6_col3" class="data row6 col3" >100</td>
#       <td id="T_9ead9_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_9ead9_row6_col5" class="data row6 col5" >06:48:B1:2E:48:C6</td>
#       <td id="T_9ead9_row6_col6" class="data row6 col6" >eth4</td>
#       <td id="T_9ead9_row6_col7" class="data row6 col7" >eth4</td>
#     </tr>
#     <tr>
#       <td id=
# Time to print interfaces 512 seconds
# Deploy Node Tools...
# Configure Node Devices...
# Configure Routers...
# Config router: router_dall
# Config router: router_salt
# Config router: router_wash
# Config router: router_utah
# waiting for router_dall config
# waiting for router_salt config
# waiting for router_wash config
# waiting for router_utah config
# Done

# %% [markdown]
# ## Run the GUI and Interact with the Experiment

# %%
#frr_experiment.load()
#print(f"here")
frr_experiment.display()
# Out:
# VBox(children=(HBox(children=(CytoscapeWidget(cytoscape_layout={'name': 'cola'}, cytoscape_style=[{'selector':…

# %% [markdown]
# ## Step 9: Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    #frr_experiment.fablib.delete_all()
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %%
frr_experiment.execute_on_all_edge_nodes("rm *output", verbose=True)

# %%
frr_experiment.execute_on_all_edge_nodes("ls", verbose=True)

# %%
frr_sites = { 'dall': { 'site': 'DALL', 'facility': 'FABRIC', 'node_count': 2 },
              'utah': { 'site': 'UTAH', 'facility': 'FABRIC', 'node_count': 2 },

              'salt': { 'site': 'SALT', 'facility': 'FABRIC', 'node_count': 2 },
              'wash': { 'site': 'WASH', 'facility': 'FABRIC', 'node_count': 2 },
              'tacc': { 'site': 'TACC', 'facility': 'FABRIC', 'node_count': 2 },
              'max':  { 'site': 'MAX', 'facility': 'FABRIC', 'node_count': 2 },
              'ncsa': { 'site': 'NCSA', 'facility': 'FABRIC', 'node_count': 2 },
              #'cham': { 'site': 'STAR', 'facility': 'CHI@UC', 'node_count': 2 },
              'mich': { 'site': 'MICH', 'facility': 'FABRIC', 'node_count': 2 },

            }
    
frr_links = { 'Link_dall_tacc': ('dall','tacc'),
              'Link_mich_ncsa': ('mich','ncsa'),
              'Link_salt_utah': ('salt','utah'),
              'Link_wash_max':  ('wash','max'),
              'Link_utah_dall': ('utah','dall'),
              'Link_dall_wash': ('dall','wash'),
              'Link_wash_mich': ('wash','mich'),
              'Link_mich_utah': ('mich','utah'),
              'Link_mich_dall': ('mich','dall'), 
            }

# %%
frr_experiment.wait_jupyter(timeout=20000)

# %%
frr_experiment.execute_on_all_edge_nodes(f'rm -rf fabric_node_tools')
print('deploy3')
frr_experiment.upload_directory_to_all_edge_nodes('fabric_node_tools','.')
print('deploy4')
frr_experiment.execute_on_all_edge_nodes(f'chmod +x fabric_node_tools/*.sh')
print('deploy5')
frr_experiment.configure_devs()
print('deploy6')

# %%
frr_experiment.configure_routers()

# %%
print('deploy7')
command = f'sudo yum install -y -q iperf3 iproute-tc && sudo ./fabric_node_tools/host_tune_redhat.sh'
frr_experiment.execute_on_all_edge_nodes(f'{command}')
print('deploy8')
