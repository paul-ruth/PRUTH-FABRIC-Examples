# %% [markdown]
# # Routing Topology: OSPF using FRRouting with Chameleon
#
# This notebook is an example of how to create a FABRIC routing experiment topology comprising nodes at three different sites. Each site has a local layer 2 (Ethernet) network connecting a set of local nodes and one gateway router. The three gateway routers connect to each other and use the [FRRouting](https://frrouting.org/) protocol suite to deploy [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) dameons to propagate route updates across the topology.
#
# You might be familiar with the [Quagga](https://www.quagga.net/) router suite.  FRRouting is based on Quagga but has a more active upstream community including many large companies working on cloud networking.
#
#
# ## Configure the Environment

# %%
import os
import sys

module_path = os.path.abspath(os.path.join(f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fablib_local"))
if module_path not in sys.path:
    sys.path.append(module_path)

from chameleon_utils.chameleon_config import *

load_chameleon_rc_environment(chameleon_rc_file=f"{os.environ['HOME']}/work/fablib_local_private_config/Chameleon-openrc.sh")

from my_experiment.frrouting_experiment import FRRouting_Experiment

# %% [markdown]
# ## Create the Experiment

# %%
frr_experiment = FRRouting_Experiment('FRRouting_OSPF_SC22')

# %% [markdown]
# ## (Optional): Query for Available Tesbed Resources and Settings

# %%
try:
    frr_experiment.list_sites()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_7434c caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_7434c th {
#   text-align: left;
# }
# #T_7434c tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7434c tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7434c .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7434c_row0_col0, #T_7434c_row0_col1, #T_7434c_row0_col2, #T_7434c_row0_col3, #T_7434c_row0_col4, #T_7434c_row0_col5, #T_7434c_row0_col6, #T_7434c_row0_col7, #T_7434c_row0_col8, #T_7434c_row0_col9, #T_7434c_row0_col10, #T_7434c_row0_col11, #T_7434c_row0_col12, #T_7434c_row0_col13, #T_7434c_row0_col14, #T_7434c_row0_col15, #T_7434c_row0_col16, #T_7434c_row0_col17, #T_7434c_row0_col18, #T_7434c_row0_col19, #T_7434c_row0_col20, #T_7434c_row0_col21, #T_7434c_row0_col22, #T_7434c_row0_col23, #T_7434c_row0_col24, #T_7434c_row0_col25, #T_7434c_row0_col26, #T_7434c_row0_col27, #T_7434c_row0_col28, #T_7434c_row0_col29, #T_7434c_row0_col30, #T_7434c_row0_col31, #T_7434c_row1_col0, #T_7434c_row1_col1, #T_7434c_row1_col2, #T_7434c_row1_col3, #T_7434c_row1_col4, #T_7434c_row1_col5, #T_7434c_row1_col6, #T_7434c_row1_col7, #T_7434c_row1_col8, #T_7434c_row1_col9, #T_7434c_row1_col10, #T_7434c_row1_col11, #T_7434c_row1_col12, #T_7434c_row1_col13, #T_7434c_row1_col14, #T_7434c_row1_col15, #T_7434c_row1_col16, #T_7434c_row1_col17, #T_7434c_row1_col18, #T_7434c_row1_col19, #T_7434c_row1_col20, #T_7434c_row1_col21, #T_7434c_row1_col22, #T_7434c_row1_col23, #T_7434c_row1_col24, #T_7434c_row1_col25, #T_7434c_row1_col26, #T_7434c_row1_col27, #T_7434c_row1_col28, #T_7434c_row1_col29, #T_7434c_row1_col30, #T_7434c_row1_col31, #T_7434c_row2_col0, #T_7434c_row2_col1, #T_7434c_row2_col2, #T_7434c_row2_col3, #T_7434c_row2_col4, #T_7434c_row2_col5, #T_7434c_row2_col6, #T_7434c_row2_col7, #T_7434c_row2_col8, #T_7434c_row2_col9, #T_7434c_row2_col10, #T_7434c_row2_col11, #T_7434c_row2_col12, #T_7434c_row2_col13, #T_7434c_row2_col14, #T_7434c_row2_col15, #T_7434c_row2_col16, #T_7434c_row2_col17, #T_7434c_row2_col18, #T_7434c_row2_col19, #T_7434c_row2_col20, #T_7434c_row2_col21, #T_7434c_row2_col22, #T_7434c_row2_col23, #T_7434c_row2_col24, #T_7434c_row2_col25, #T_7434c_row2_col26, #T_7434c_row2_col27, #T_7434c_row2_col28, #T_7434c_row2_col29, #T_7434c_row2_col30, #T_7434c_row2_col31, #T_7434c_row3_col0, #T_7434c_row3_col1, #T_7434c_row3_col2, #T_7434c_row3_col3, #T_7434c_row3_col4, #T_7434c_row3_col5, #T_7434c_row3_col6, #T_7434c_row3_col7, #T_7434c_row3_col8, #T_7434c_row3_col9, #T_7434c_row3_col10, #T_7434c_row3_col11, #T_7434c_row3_col12, #T_7434c_row3_col13, #T_7434c_row3_col14, #T_7434c_row3_col15, #T_7434c_row3_col16, #T_7434c_row3_col17, #T_7434c_row3_col18, #T_7434c_row3_col19, #T_7434c_row3_col20, #T_7434c_row3_col21, #T_7434c_row3_col22, #T_7434c_row3_col23, #T_7434c_row3_col24, #T_7434c_row3_col25, #T_7434c_row3_col26, #T_7434c_row3_col27, #T_7434c_row3_col28, #T_7434c_row3_col29, #T_7434c_row3_col30, #T_7434c_row3_col31, #T_7434c_row4_col0, #T_7434c_row4_col1, #T_7434c_row4_col2, #T_7434c_row4_col3, #T_7434c_row4_col4, #T_7434c_row4_col5, #T_7434c_row4_col6, #T_7434c_row4_col7, #T_7434c_row4_col8, #T_7434c_row4_col9, #T_7434c_row4_col10, #T_7434c_row4_col11, #T_7434c_row4_col12, #T_7434c_row4_col13, #T_7434c_row4_col14, #T_7434c_row4_col15, #T_7434c_row4_col16, #T_7434c_row4_col17, #T_7434c_row4_col18, #T_7434c_row4_col19, #T_7434c_row4_col20, #T_7434c_row4_col21, #T_7434c_row4_col22, #T_7434c_row4_col23, #T_7434c_row4_col24, #T_7434c_row4_col25, #T_7434c_row4_col26, #T_7434c_row4_col27, #T_7434c_row4_col28, #T_7434c_row4_col29, #T_7434c_row4_col30, #T_7434c_row4_col31, #T_7434c_row5_col0, #T_7434c_row5_col1, #T_7434c_row5_col2, #T_7434c_row5_col3, #T_7434c_row5_col4, #T_7434c_row5_col5, #T_7434c_row5_col6, #T_7434c_row5_col7, #T_7434c_row5_col8, #T_7434c_row5_col9, #T_7434c_row5_col10, #T_7434c_row5_col11, #T_7434c_row5_col12, #T_7434c_row5_col13, #T_7434c_row5_col14, #T_7434c_row5_col15, #T_7434c_row5_col16, #T_7434c_row5_col17, #T_7434c_row5_col18, #T_7434c_row5_col19, #T_7434c_row5_col20, #T_7434c_row5_col21, #T_7434c_row5_col22, #T_7434c_row5_col23, #T_7434c_row5_col24, #T_7434c_row5_col25, #T_7434c_row5_col26, #T_7434c_row5_col27, #T_7434c_row5_col28, #T_7434c_row5_col29, #T_7434c_row5_col30, #T_7434c_row5_col31, #T_7434c_row6_col0, #T_7434c ...

# %% [markdown]
# ## Define Experiment
#
# The following creates private layer 2 networks on three sites including a OSPF gateway routers that propogate routes acrross the topology.

# %%
frr_sites = { 'dall': { 'site': 'DALL', 'facility': 'FABRIC', 'node_count': 2 },
              'salt': { 'site': 'SALT', 'facility': 'FABRIC', 'node_count': 2 },
              #'cham': { 'site': 'STAR', 'facility': 'CHI@UC', 'node_count': 2 },
              'mich': { 'site': 'MICH', 'facility': 'FABRIC', 'node_count': 2 },
              'utah': { 'site': 'UTAH', 'facility': 'FABRIC', 'node_count': 2 }
            }
    
frr_links = { 'Link12': ('dall','salt'),
              'Link23': ('salt','mich'),
              'Link31': ('mich','dall'),
              'Link24': ('utah','salt')
            }

# %%
frr_experiment.configure(frr_sites, frr_links)

# %%
frr_experiment.deploy()
# Out:
# Submit FABRIC Slice...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 frr_experiment.deploy()
#
# File ~/work/PRUTH-FABRIC-Examples/SC22/FRRouting/my_experiment/frrouting_experiment.py:155, in FRRouting_Experiment.deploy(self)
#     153 def deploy(self):
#     154     print('Submit FABRIC Slice...')
# --> 155     self.submit()
#     156     print('Deploy Node Tools...')
#     157     self.execute_on_all_edge_nodes(f'rm -rf fabric_node_tools')
#
# File ~/work/PRUTH-FABRIC-Examples/SC22/FRRouting/my_experiment/frrouting_experiment.py:814, in FRRouting_Experiment.submit(self)
#     812 def submit(self):
#     813     #self.slice_id = self.slice.submit(wait=False)
# --> 814     self.slice_id = self.slice.submit(wait_timeout=10000)
#     816     self.save_config()
#
# File ~/Library/Python/3.9/lib/python/site-packages/fabrictestbed_extensions/fablib/slice.py:1551, in Slice.submit(self, wait, wait_timeout, wait_interval, progress, wait_jupyter)
#    1546     return_status, slice_reservations = self.fablib_manager.get_slice_manager().create(
#    1547         slice_name=self.slice_name,
#    1548         slice_graph=slice_graph,
#    1549         ssh_key=self.get_slice_public_key())
#    1550 if return_status != Status.OK:
# -> 1551     raise Exception("Failed to submit slice: {}, {}".format(return_status, slice_reservations))
#    1553 logging.debug(f'slice_reservations: {slice_reservations}')
#    1554 logging.debug(f"slice_id: {slice_reservations[0].slice_id}")
#
# Exception: Failed to submit slice: Status.FAILURE, (500)
# Reason: INTERNAL SERVER ERROR
# HTTP response headers: HTTPHeaderDict({'Server': 'nginx/1.21.6', 'Date': 'Mon, 07 Nov 2022 14:12:50 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '214', 'Connection': 'keep-alive', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'DNT, User-Agent, X-Requested-With, If-Modified-Since, Cache-Control, Content-Type, Range, Authorization', 'Access-Control-Allow-Methods': 'GET, POST, PUT, PATCH, DELETE, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Access-Control-Expose-Headers': 'Content-Length, Content-Range, X-Error', 'X-Error': 'Slice FRRouting_OSPF_SC22 already exists'})
# HTTP response body: b'{\n    "errors": [\n        {\n            "details": "Slice FRRouting_OSPF_SC22 already exists",\n            "message": "Internal Server Error"\n        }\n    ],\n    "size": 1,\n    "status": 500,\n    "type": "error"\n}'

# %% [markdown]
# ## Run the GUI and Interact with the Experiment

# %%
frr_experiment.load()
print(f"here")
frr_experiment.display()

# %% [markdown]
# ## Step 9: Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
try:
    frr_experiment.fablib.delete_all()
    #slice.delete()
except Exception as e:
    print(f"Exception: {e}")

# %%
frr_experiment.execute_on_all_edge_nodes("rm *output", verbose=True)

# %%
frr_experiment.execute_on_all_edge_nodes("ls", verbose=True)

# %%
frr_sites = { 'dall': { 'site': 'DALL', 'facility': 'FABRIC', 'node_count': 2 },
              'utah': { 'site': 'UTAH', 'facility': 'FABRIC', 'node_count': 2 },

              'salt': { 'site': 'SALT', 'facility': 'FABRIC', 'node_count': 2 },
              'wash': { 'site': 'WASH', 'facility': 'FABRIC', 'node_count': 2 },
              'tacc': { 'site': 'TACC', 'facility': 'FABRIC', 'node_count': 2 },
              'max':  { 'site': 'MAX', 'facility': 'FABRIC', 'node_count': 2 },
              'ncsa': { 'site': 'NCSA', 'facility': 'FABRIC', 'node_count': 2 },
              #'cham': { 'site': 'STAR', 'facility': 'CHI@UC', 'node_count': 2 },
              'cham': { 'site': 'STAR', 'facility': 'FABRIC', 'node_count': 2 },

            }
    
frr_links = { 'Link_dall_tacc': ('dall','tacc'),
              'Link_cham_ncsa': ('cham','ncsa'),
              'Link_salt_utah': ('salt','utah'),
              'Link_wash_max':  ('wash','max'),
              'Link_utah_dall': ('utah','dall'),
              'Link_dall_wash': ('dall','wash'),
              'Link_wash_cham': ('wash','cham'),
              'Link_cham_utah': ('cham','utah'),
              'Link_cham_dall': ('cham','dall'), 
            }

# %%
frr_experiment.wait_jupyter(timeout=20000)

# %%
frr_experiment.execute_on_all_edge_nodes(f'rm -rf fabric_node_tools')
print('deploy3')
frr_experiment.upload_directory_to_all_edge_nodes('fabric_node_tools','.')
print('deploy4')
frr_experiment.execute_on_all_edge_nodes(f'chmod +x fabric_node_tools/*.sh')
print('deploy5')
frr_experiment.configure_devs()
print('deploy6')

# %%
frr_experiment.configure_routers()

# %%
print('deploy7')
command = f'sudo yum install -y -q iperf3 iproute-tc && sudo ./fabric_node_tools/host_tune_redhat.sh'
frr_experiment.execute_on_all_edge_nodes(f'{command}')
print('deploy8')
