# %% [markdown]
# # Routing Topology: OSPF using FRRouting with Chameleon
#
# This notebook is an example of how to create a FABRIC routing experiment topology comprising nodes at three different sites. Each site has a local layer 2 (Ethernet) network connecting a set of local nodes and one gateway router. The three gateway routers connect to each other and use the [FRRouting](https://frrouting.org/) protocol suite to deploy [OSPF](https://en.wikipedia.org/wiki/Open_Shortest_Path_First) dameons to propagate route updates across the topology.
#
# You might be familiar with the [Quagga](https://www.quagga.net/) router suite.  FRRouting is based on Quagga but has a more active upstream community including many large companies working on cloud networking.
#
#
# ## Configure the Environment

# %%
import os
import sys

module_path = os.path.abspath(os.path.join(f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fablib_local"))
if module_path not in sys.path:
    sys.path.append(module_path)
from fablib_custom.fablib_custom import *

from chameleon_utils.chameleon_config import *

load_chameleon_rc_environment(chameleon_rc_file=f"{os.environ['HOME']}/work/fablib_local_private_config/Chameleon-openrc.sh")

from my_experiment.frrouting_experiment import FRRouting_Experiment

# %% [markdown]
# ## Create the Experiment

# %%
import json
  
f = open('config/chameleon_four.json')
ffr_config = json.load(f)
f.close()

frr_experiment = FRRouting_Experiment('FRRouting_OSPF_SC22', config=ffr_config)
#print(f"{json.dumps(ffr_config, indent = 4)}")

# %% [markdown]
# ## (Optional): Query for Available Tesbed Resources and Settings

# %%
try:
    frr_experiment.list_sites()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_9163c caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_9163c th {
#   text-align: left;
# }
# #T_9163c tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9163c tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9163c .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9163c_row0_col0, #T_9163c_row0_col1, #T_9163c_row0_col2, #T_9163c_row0_col3, #T_9163c_row0_col4, #T_9163c_row0_col5, #T_9163c_row0_col6, #T_9163c_row0_col7, #T_9163c_row0_col8, #T_9163c_row0_col9, #T_9163c_row0_col10, #T_9163c_row0_col11, #T_9163c_row0_col12, #T_9163c_row0_col13, #T_9163c_row0_col14, #T_9163c_row0_col15, #T_9163c_row0_col16, #T_9163c_row0_col17, #T_9163c_row0_col18, #T_9163c_row0_col19, #T_9163c_row0_col20, #T_9163c_row0_col21, #T_9163c_row0_col22, #T_9163c_row0_col23, #T_9163c_row0_col24, #T_9163c_row0_col25, #T_9163c_row0_col26, #T_9163c_row0_col27, #T_9163c_row0_col28, #T_9163c_row0_col29, #T_9163c_row0_col30, #T_9163c_row0_col31, #T_9163c_row1_col0, #T_9163c_row1_col1, #T_9163c_row1_col2, #T_9163c_row1_col3, #T_9163c_row1_col4, #T_9163c_row1_col5, #T_9163c_row1_col6, #T_9163c_row1_col7, #T_9163c_row1_col8, #T_9163c_row1_col9, #T_9163c_row1_col10, #T_9163c_row1_col11, #T_9163c_row1_col12, #T_9163c_row1_col13, #T_9163c_row1_col14, #T_9163c_row1_col15, #T_9163c_row1_col16, #T_9163c_row1_col17, #T_9163c_row1_col18, #T_9163c_row1_col19, #T_9163c_row1_col20, #T_9163c_row1_col21, #T_9163c_row1_col22, #T_9163c_row1_col23, #T_9163c_row1_col24, #T_9163c_row1_col25, #T_9163c_row
5_col13, #T_9163c_row5_col14, #T_9163c_row5_col15, #T_9163c_row5_col16, #T_9163c_row5_col17, #T_9163c_row5_col18, #T_9163c_row5_col19, #T_9163c_row5_col20, #T_9163c_row5_col21, #T_9163c_row5_col22, #T_9163c_row5_col23, #T_9163c_row5_col24, #T_9163c_row5_col25, #T_9163c_row5_col26, #T_9163c_row5_col27, #T_9163c_row5_col28, #T_9163c_row5_col29, #T_9163c_row5_col30, #T_9163c_row5_col31, #T_9163c_row6_col0, #T_9163c ...

# %% [markdown]
# ## Define Experiment
#
# The following creates private layer 2 networks on three sites including a OSPF gateway routers that propogate routes acrross the topology.

# %%
frr_experiment.configure()
# Out:
# Retry: 3, Time: 555 sec
# <style type="text/css">
# #T_f08dd tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_f08dd tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f08dd caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_f08dd_row0_col0, #T_f08dd_row0_col1, #T_f08dd_row1_col0, #T_f08dd_row1_col1, #T_f08dd_row2_col0, #T_f08dd_row2_col1, #T_f08dd_row3_col0, #T_f08dd_row3_col1, #T_f08dd_row4_col0, #T_f08dd_row4_col1, #T_f08dd_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_f08dd_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_f08dd">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f08dd_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_f08dd_row0_col1" class="data row0 col1" >9655bbdd-58b4-48b8-be53-547da25d20d0</td>
#     </tr>
#     <tr>
#       <td id="T_f08dd_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_f08dd_row1_col1" class="data row1 col1" >FRRouting_OSPF_SC22</td>
#     </tr>
#     <tr>
#       <td id="T_f08dd_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_f08dd_row2_col1" class="data row2 col1" >2022-11-14 20:38:31 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_f08dd_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_f08dd_row3_col1" class="data row3 col1" >2022-11-13 20:38:32 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_f08dd_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_f08dd_row4_col1" class="data row4 col1" >990d8a8b-7e50-4d13-a3be-0f133ffa8653</td>
#     </tr>
#     <tr>
#       <td id="T_f08dd_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_f08dd_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_97c8e caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_97c8e th {
#   text-align: left;
# }
# #T_97c8e tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_97c8e tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_97c8e .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_97c8e_row0_col0, #T_97c8e_row0_col1, #T_97c8e_row0_col2, #T_97c8e_row0_col3, #T_97c8e_row0_col4, #T_97c8e_row0_col5, #T_97c8e_row0_col6, #T_97c8e_row0_col7, #T_97c8e_row0_col8, #T_97c8e_row0_col9, #T_97c8e_row0_col10, #T_97c8e_row0_col13, #T_97c8e_row0_col14, #T_97c8e_row0_col15, #T_97c8e_row1_col0, #T_97c8e_row1_col1, #T_97c8e_row1_col2, #T_97c8e_row1_col3, #T_97c8e_row1_col4, #T_97c8e_row1_col5, #T_97c8e_row1_col6, #T_97c8e_row1_col7, #T_97c8e_row1_col8, #T_97c8e_row1_col9, #T_97c8e_row1_col10, #T_97c8e_row1_col13, #T_97c8e_row1_col14, #T_97c8e_row1_col15, #T_97c8e_row2_col0, #T_97c8e_row2_col1, #T_97c8e_row2_col2, #T_97c8e_row2_col3, #T_97c8e_row2_col4, #T_97c8e_row2_col5, #T_97c8e_row2_col6, #T_97c8e_row2_col7, #T_97c8e_row2_col8, #T_97c8e_row2_col9, #T_97c8e_row2_col10, #T_97c8e_row2_col13, #T_97c8e_row2_col14, #T_97c8e_row2_col15, #T_97c8e_row3_col0, #T_97c8e_row3_col1, #T_97c8e_row3_col2, #T
col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_97c8e_row0_col12, #T_97c8e_row1_col12, #T_97c8e_row2_col12, #T_97c8e_row3_col12, #T_97c8e_row4_col12, #T_97c8e_row5_col12, #T_97c8e_row6_col12, #T_97c8e_row7_col12, #T_97c8e_row8_col12, #T_97c8e_row9_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_97c8e">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_97c8e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_97c8e_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_97c8e_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_97c8e_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_97c8e_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_97c8e_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_97c8e_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_97c8e_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_97c8e_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_97c8e_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_97c8e_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_97c8e_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_97c8e_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_97c8e_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_97c8e_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_97c8e_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_97c8e_row0_col0" class="data row0 col0" >c8a43296-237a-432b-b538-24d0d4b49faa</td>
#       <td id="T_97c8e_row0_col1" class="data row0 col1" >chameleon_router</td>
#       <td id="T_97c8e_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_97c8e_row0_col3" class="data row0 col3" >32</td>
#       <td id="T_97c8e_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_97c8e_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_97c8e_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_97c8e_row0_col7" class="data row0 col7" >mich-w1.fabric-testbed.net</td>
#       <td id="T_97c8e_row0_col8" class="data row0 col8" >MICH</td>
#       <td id="T_97c8e_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_97c8e_row0_col10" class="data row0 col10" >2607:f018:110:11:f816:3eff:fef2:158f</td>
#       <td id="T_97c8e_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_97c8e_row0_col12" class="data row0 col12" ></td>
#       <td id="T_97c8e_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2607:f018:110:11:f816:3eff:fef2:158f</td>
#       <td id="T_97c8e_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_97c8e_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_97c8e_row1_col0" class="data row1 col0" >bf00bacf-d9ad-4c46-b708-224d0286f6ca</td>
#       <td id="T_97c8e_row1_col1" class="data row1 col1" >dall_router</td>
#       <td id="T_97c8e_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_97c8e_row1_col3" class="data row1 col3" >32</td>
#       <td id="T_97c8e_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_97c8e_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_97c8e_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_97c8e_row1_col7" class="data row1 col7" >dall-w1.fabric-testbed.net</td>
#       <td id="T_97c8e_row1_col8" class="data row1 col8" >DALL</td>
#       <td id="T_97c8e_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_97c8e_row1_col10" class="data row1 col10" >2001:400:a100:3000:f816:3eff:fecf:2016</td>
#       <td id="T_97c8e_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_97c8e_row1_col12" class="data row1 col12" ></td>
#       <td id="T_97c8e_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fecf:2016</td>
#       <td id="T_97c8e_
# <style type="text/css">
# #T_3dfea caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_3dfea th {
#   text-align: left;
# }
# #T_3dfea tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3dfea tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_3dfea .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_3dfea_row0_col0, #T_3dfea_row0_col1, #T_3dfea_row0_col2, #T_3dfea_row0_col3, #T_3dfea_row0_col4, #T_3dfea_row0_col5, #T_3dfea_row0_col6, #T_3dfea_row1_col0, #T_3dfea_row1_col1, #T_3dfea_row1_col2, #T_3dfea_row1_col3, #T_3dfea_row1_col4, #T_3dfea_row1_col5, #T_3dfea_row1_col6, #T_3dfea_row2_col0, #T_3dfea_row2_col1, #T_3dfea_row2_col2, #T_3dfea_row2_col3, #T_3dfea_row2_col4, #T_3dfea_row2_col5, #T_3dfea_row2_col6, #T_3dfea_row3_col0, #T_3dfea_row3_col1, #T_3dfea_row3_col2, #T_3dfea_row3_col3, #T_3dfea_row3_col4, #T_3dfea_row3_col5, #T_3dfea_row3_col6, #T_3dfea_row4_col0, #T_3dfea_row4_col1, #T_3dfea_row4_col2, #T_3dfea_row4_col3, #T_3dfea_row4_col4, #T_3dfea_row4_col5, #T_3dfea_row4_col
row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_3dfea_row5_col0" class="data row5 col0" >5bd9606b-aa37-4782-a970-79e6b5e7d48a</td>
#       <td id="T_3dfea_row5_col1" class="data row5 col1" >dall</td>
#       <td id="T_3dfea_row5_col2" class="data row5 col2" >L2</td>
#       <td id="T_3dfea_row5_col3" class="data row5 col3" >L2Bridge</td>
#       <td id="T_3dfea_row5_col4" class="data row5 col4" >DALL</td>
#       <td id="T_3dfea_row5_col5" class="data row5 col5" >None</td>
#       <td id="T_3dfea_row5_col6" class="data row5 col6" >None</td>
#       <td id="T_3dfea_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_3dfea_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_3dfea_row6_col0" class="data row6 col0" >325d821e-8995-4b03-b7ad-83db774ba639</td>
#       <td id="T_3dfea_row6_col1" class="data row6 col1" >tacc</td>
#       <td id="T_3dfea_row6_col2" class="data row6 col2" >L2</td>
#       <td id="T_3dfea_row6_col3" class="data row6 col3" >L2Bridge</td>
#       <td id="T_3dfea_row6_col4" class="data row6 col4" >TACC</td>
#       <td id="T_3dfea_row6_col5" class="data row6 col5" >None</td>
#       <td id="T_3dfea_row6_col6" class="data row6 col6" >None</td>
#       <td id="T_3dfea_row6_col7" class="data row6 col7" >Active</td>
#       <td id="T_3dfea_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_3dfea_row7_col0" class="data row7 col0" >f24ba8ef-5e39-4431-9d23-512983b02837</td>
#       <td id="T_3dfea_row7_col1" class="data row7 col1" >utah</td>
#       <td id="T_3dfea_row7_col2" class="data row7 col2" >L2</td>
#       <td id="T_3dfea_row7_col3" class="data row7 col3" >L2Bridge</td>
#       <td id="T_3dfea_row7_col4" class="data row7 col4" >UTAH</td>
#       <td id="T_3dfea_row7_col5" class="data row7 col5" >None</td>
#       <td id="T_3dfea_row7_col6" clas
# Time to stable 555 seconds
# Running post_boot_config ... Time to post boot config 574 seconds
# <style type="text/css">
# #T_dd7f2 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_dd7f2 th {
#   text-align: left;
# }
# #T_dd7f2 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dd7f2 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_dd7f2 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_dd7f2_row0_col0, #T_dd7f2_row0_col1, #T_dd7f2_row0_col2, #T_dd7f2_row0_col3, #T_dd7f2_row0_col4, #T_dd7f2_row0_col5, #T_dd7f2_row0_col6, #T_dd7f2_row0_col7, #T_dd7f2_row1_col0, #T_dd7f2_row1_col1, #T_dd7f2_row1_col2, #T_dd7f2_row1_col3, #T_dd7f2_row1_col4, #T_dd7f2_row1_col5, #T_dd7f2_row1_col6, #T_dd7f2_row1_col7, #T_dd7f2_row2_col0, #T_dd7f2_row2_col1, #T_dd7f2_row2_col2, #T_dd7f2_row2_col3, #T_dd7f2_row2_col4, #T_dd7f2_row2_col5, #T_dd7f2_row2_col6, #T_dd7f2_row2_col7, #T_dd7f2_row3_col0, #T_dd7f2_row3_col1, #T_dd7f2_row3_col2, #T_dd7f2_row3_col3, #T_dd7f2_row3_col4, #T_dd7f2_row3_col5, #T_dd7f2_row3_col6, #T_dd7f2_row3_col7, #T_dd7f2_row4_col0, #T_dd7f2_row4_col1, #T_dd7f2_row4_col2, #T_dd7f2_row4_col3, #T_dd7f2_row4_col4, #T_dd7f2_row4_col5, #T_dd7f2_row4_col6, #T_dd7f2_row4_col7, #T_dd7f2_row5_col0, #T_dd7f2_row5_col1, #T_dd7f2_row5_col2, #T_dd7f2_row5_col3, #T_dd7f2_row5_col4, #T_dd7f2_row5_col5, #T_dd7f2_row5_col6, #T_dd7f2_row5_col7, #T_dd7f2_row6_col0, #T_dd7f2_row6_col1, #T_dd7f2_row6_col2, #T_dd7f2_row6_col3, #T_dd7f2_row6_col4, #T_dd7f2_row6_col5, #T_dd7f2_row6_col6, #T_dd7f2_row6_col7, #T_dd7f2_row7_col0, #T_dd7f2_row7_col1, #T_dd7f2_row7_col2, #T_dd7f2_row7_col3, #T_dd7f2_row7_col4, #T_dd7f2_row7_col5, #T_dd7f2_row7_col6, #T_dd7f2_row7_col7, #T_dd7f2_row8_col0, #T_dd7f2_row8_col1, #T_dd7f2_row8_col2, #T_dd7f2_row8_col3, #T_dd7f2_row8_col4, #T_dd7f2_row8_col5, #T_dd7f2_row8_col6, #T_dd7f2_row8_col7, #T_dd7f2_row9_col0, #T_dd7f2_row9_col1, #T_dd7f2_row9_col2, #T_dd7f2_row9_col3, #T_dd7f2_row9_col4, #T_dd7f2_row9_col5, #T_dd7f2_row9_col6, #T_dd7f2_row9_col7, #T_dd7f2_row10_col0, #T_dd7f2_row10_col1, #T_dd7f2_row10_col2, #T_dd7f2_row10_col3, #T_dd7f2_row10_col4, #T_dd7f2_row10_col5, #T_dd7f2_row10_col6, #T_dd7f2_row10_col7, #T_dd7f2_row11_col0, #T_dd7f2_row11_col1, #T_dd7f2_row11_col2, #T_dd7f2_row11_col3, #T_dd7f2_row11_col4, #T_dd7f2_row11_col5, #T_dd7f2_row11_col6, #T_dd7f2_row11_col7, #T_dd7f2_row12_col0, #T_dd7f2_row12_col1, #T_dd7f2_row12_col2, #T_dd7f2_row12_col3, #T_dd7f2_row12_col4, #T_dd7f2_row12_col5, #T_dd7f2_row12_col6, #T_dd7f2_row12_col7, #T_dd7f2_row13_col0, #T_dd7f2_row13_col1, #T_dd7f2_row13_col2, #T_dd7f2_row13_col3, #T_dd7f2_row13_col4, #T_dd7f2_row13_col5, #T_dd7f2_row13_col6, #T_dd7f2_row13_col7, #T_dd7f2_row14_col0, #T_dd7f2_row14_col1, #T_dd7f2_row14_col2, #T_dd7f2_row14_col3, #T_dd7f2_row14_col4, #T_dd7f2_row14_col5, #T_dd7f2_row14_col6, #T_dd7f2_row14_col7, #T_dd7f2_row15_col0, #T_dd7f2_row15_col1, #T_dd7f2_row15_col2, #T_dd7f2_row15_col3, #T_dd7f2_row15_col4, #T_dd7f2_row15_col5, #T_dd7f2_row15_col6, #T_dd7f2_row15_col7, #T_dd7f2_row16_col0, #T_dd7f2_row16_col1, #T_dd7f2_row16_col2, #T_dd7f2_row16_col3, #T_dd7f2_row16_col4, #T_dd7f2_row16_col5, #T_dd7f2_row16_col6, #T_dd7f2_row16_col7, #T_dd7f2_row17_col0, #T_dd7f2_row17_col1, #T_dd7f2_row17_col2, #T_dd7f2_row17_col3, #T_dd7f2_row17_col4, #T_dd7f2_row17_col5, #T_dd7f2_row17_col6, #T_dd7f2_row17_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_dd7f2">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_dd7f2_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_dd7f2_level0_col1" class="col_heading level0 col1" >Node</th>
#       <th id="T_dd7f2_level0_col2" class="col_heading level0 col2" >Network</th>
#       <th id="T_dd7f2_level0_col3" class="col_heading level0 col3" >Bandwidth</th>
#       <th id="T_dd7f2_level0_col4" class="col_heading level0 col4" >VLAN</th>
#       <th id="T_dd7f2_level0_col5" class="col_heading level0 col5" >MAC</th>
#       <th id="T_dd7f2_level0_col6" class="col_heading level0 col6" >Physical Device</th>
#       <th id="T_dd7f2_level0_col7" class="col_heading level0 col7" >Device</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dd7f2_row0_col0" class="data row0 col0" >chameleon_router-link2-p1</td>
#       <td id="T_dd7f2_row0_col1" class="data row0 col1" >chameleon_router</td>
#       <td id="T_dd7f2_row0_col2" class="data row0 col2" >link2</td>
#       <td id="T_dd7f2_row0_col3" class="data row0 col3" >100</td>
#       <td id="T_dd7f2_row0_col4" class="data row0 col4" >None</td>
#       <td id="T_dd7f2_row0_col5" class="data row0 col5" >0A:44:2E:A3:7B:F8</td>
#       <td id="T_dd7f2_row0_col6" class="data row0 col6" >eth3</td>
#       <td id="T_dd7f2_row0_col7" class="data row0 col7" >eth3</td>
#     </tr>
#     <tr>
#       <td id="T_dd7f2_row1_col0" class="data row1 col0" >chameleon_router-link0-p1</td>
#       <td id="T_dd7f2_row1_col1" class="data row1 col1" >chameleon_router</td>
#       <td id="T_dd7f2_row1_col2" class="data row1 col2" >link0</td>
#       <td id="T_dd7f2_row1_col3" class="data row1 col3" >100</td>
#       <td id="T_dd7f2_row1_col4" class="data row1 col4" >None</td>
#       <td id="T_dd7f2_row1_col5" class="data row1 col5" >02:B3:F5:DB:97:7C</td>
#       <td id="T_dd7f2_row1_col6" class="data row1 col6" >eth1</td>
#       <td id="T_dd7f2_row1_col7" class="data row1 col7" >eth1</td>
#     </tr>
#     <tr>
#       <td id="T_dd7f2_row2_col0" class="data row2 col0" >chameleon_router-local-p1</td>
#       <td id="T_dd7f2_row2_col1" class="data row2 col1" >chameleon_router</td>
#       <td id="T_dd7f2_row2_col2" class="data row2 col2" >chameleon</td>
#       <td id="T_dd7f2_row2_col3" class="data row2 col3" >100</td>
#       <td id="T_dd7f2_row2_col4" class="data row2 col4" >None</td>
#       <td id="T_dd7f2_row2_col5" class="data row2 col5" >06:1D:A4:2D:F2:99</td>
#       <td id="T_dd7f2_row2_col6" class="data row2 col6" >eth2</td>
#       <td id="T_dd7f2_row2_col7" class="data row2 col7" >eth2</td>
#     </tr>
#     <tr>
#       <td id="T_dd7f2_row3_col0" class="data row3 col0" >dall_router-link0-p1</td>
#       <td id="T_dd7f2_row3_col1" class="data row3 col1" >dall_router</td>
#       <td id="T_dd7f2_row3_col2" class="data row3 col2" >link0</td>
#       <td id="T_dd7f2_row3_col3" class="data row3 col3" >100</td>
#       <td id="T_dd7f2_row3_col4" class="data row3 col4" >None</td>
#       <td id="T_dd7f2_row3_col5" class="data row3 col5" >02:76:DD:CA:86:30</td>
#       <td id="T_dd7f2_row3_col6" class="data row3 col6" >eth2</td>
#       <td id="T_dd7f2_row3_col7" class="data row3 col7" >eth2</td>
#     </tr>
#     <tr>
#       <td id="T_dd7f2_row4_col0" class="data row4 col0" >dall_router-link1-p1</td>
#       <td id="T_dd7f2_row4_col1" class="data row4 col1" >dall_router</td>
#       <td id="T_dd7f2_row4_col2" class="data row4 col2" >link1</td>
#       <td id="T_dd7f2_row4_col3" class="data row4 col3" >100</td>
#       <td id="T_dd7f2_row4_col4" class="data row4 col4" >None</td>
#       <td id="T_dd7f2_row4_col5" class="data row4 col5" >16:43:28:3B:FE:F6</td>
#       <td id="T_dd7f2_row4_col6" class="data row4 col6" >eth4</td>
#       <td id="T_dd7f2_row4_col7" class="data row4 col7" >eth4</td>
#     </tr>
#     <tr>
#       <td id="T_dd7f2_row5_col0" class="data row5 col0" >dall_router-link3-p1</td>
#       <td id="T_dd7f2_row5_col1" class="data row5 col1" >dall_router</td>
#       <td id="T_dd7f2_row5_col2" class="data row5 col2" >link3</td>
#       <td id="T_dd7f2_row5_col3" class="data row5 col3" >100</td>
#       <td id="T_dd7f2_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_dd7f2_row5_col5" class="data row5 col5" >02:98:24:4F:AE:C2</td>
#       <td id="T_dd7f2_row5_col6" class="data row5 col6" >eth3</td>
#       <td id="T_dd7f2_row5_col7" class="data row5 col7" >eth3</td>
#     </tr>
#     <tr>
#       <td id="T_dd7f2_row6_col0" class="data row6 col0" >dall_router-local-p1</td>
#       <td id="T_dd7f2_row6_col1" class="data row6 col1" >dall_router</td>
#       <td id="T_dd7f2_row6_col2" class="data row6 col2" >dall</td>
#       <td id="T_
# Time to print interfaces 610 seconds

# %%
frr_experiment.slice.list_nodes()
# Out:
# <style type="text/css">
# #T_622bb caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_622bb th {
#   text-align: left;
# }
# #T_622bb tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_622bb tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_622bb .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_622bb_row0_col0, #T_622bb_row0_col1, #T_622bb_row0_col2, #T_622bb_row0_col3, #T_622bb_row0_col4, #T_622bb_row0_col5, #T_622bb_row0_col6, #T_622bb_row0_col7, #T_622bb_row0_col8, #T_622bb_row0_col9, #T_622bb_row0_col10, #T_622bb_row0_col11, #T_622bb_row0_col12, #T_622bb_row0_col13, #T_622bb_row0_col14, #T_622bb_row0_col15, #T_622bb_row1_col0, #T_622bb_row1_col1, #T_622bb_row1_col2, #T_622bb_row1_col3, #T_622bb_row1_col4, #T_622bb_row1_col5, #T_622bb_row1_col6, #T_622bb_row1_col7, #T_622bb_row1_col8, #T_622bb_row1_col9, #T_622bb_row1_col10, #T_622bb_row1_col11, #T_622bb_row1_col12, #T_622bb_row1_col13, #T_622bb_row1_col14, #T_622bb_row1_col15, #T_622bb_row2_col0, #T_622bb_row2_col1, #T_622bb_row2_col2, #T_622bb_row2_col3, #T_622bb_row2_col4, #T_622bb_row2_col5, #T_622bb_row2_col6, #T_622bb_row2_col7, #T_622bb_row2_col8, #T_622bb_row2_col9, #T_622bb_row2_col10, #T_622bb_row2_col11, #T_622bb_row2_col12, #T_622bb_row2_col13, #T_622bb_row2_col14, #T_622bb_row2_col15, #T_622bb_row3_col0, #T_622bb_row3_col1, #T_622bb_row3_col2, #T_622bb_row3_col3, #T_622bb_row3_col4, #T_622bb_row3_col5, #T_622bb_row3_col6, #T_622bb_row3_col7, #T_622bb_row3_col8, #T_622bb_row3_col9, #T_622bb_row3_col10, #T_622bb_row3_col11, #T_622bb_row3_col12, #T_622bb_row3_col13, #T_622bb_row3_col14, #T_622bb_row3_col15, #T_622bb_row4_col0, #T_622bb_row4_col1, #T_622bb_row4_col2, #T_622bb_row4_col3, #T_622bb_row4_col4, #T_622bb_row4_col5, #T_622
row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_622bb_row0_col12" class="data row0 col12" ></td>
#       <td id="T_622bb_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2607:f018:110:11:f816:3eff:fef2:158f</td>
#       <td id="T_622bb_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_622bb_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_622bb_row1_col0" class="data row1 col0" >bf00bacf-d9ad-4c46-b708-224d0286f6ca</td>
#       <td id="T_622bb_row1_col1" class="data row1 col1" >dall_router</td>
#       <td id="T_622bb_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_622bb_row1_col3" class="data row1 col3" >32</td>
#       <td id="T_622bb_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_622bb_row1_col5" class="data row1 col5" >default_rocky_8</td>
#       <td id="T_622bb_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_622bb_row1_col7" class="data row1 col7" >dall-w1.fabric-testbed.net</td>
#       <td id="T_622bb_row1_col8" class="data row1 col8" >DALL</td>
#       <td id="T_622bb_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_622bb_row1_col10" class="data row1 col10" >2001:400:a100:3000:f816:3eff:fecf:2016</td>
#       <td id="T_622bb_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_622bb_row1_col12" class="data row1 col12" ></td>
#       <td id="T_622bb_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3000:f816:3eff:fecf:2016</td>
#       <td id="T_622bb_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_622bb_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>

# %%
frr_experiment.save_config(path='run_data')

# %%
frr_experiment.load(slice_name='FRRouting_OSPF_SC22', path='run_data')

print(f"{json.dumps(frr_experiment.config, indent=4)}")
# Out:
# {
#     "slice": {},
#     "networks": [
#         {
#             "name": "chameleon",
#             "site": "STAR",
#             "facility": "CHI@UC",
#             "subnet": "192.168.1.0/24",
#             "allocation_pool_start": "192.168.1.10",
#             "allocation_pool_end": "192.168.1.250",
#             "chameleon_gateway_ip": "192.168.1.2",
#             "router": {
#                 "name": "chameleon_router",
#                 "facility": "FABRIC",
#                 "site": "MICH",
#                 "network": "cham",
#                 "ip": "192.168.1.1",
#                 "cores": "8",
#                 "ram": "32",
#                 "disk": "10",
#                 "static_routes": []
#             }
#         },
#         {
#             "name": "dall",
#             "site": "DALL",
#             "facility": "FABRIC",
#             "subnet": "192.168.2.0/24",
#             "router": {
#                 "name": "dall_router",
#                 "facility": "FABRIC",
#                 "network": "dall",
#                 "site": "DALL",
#                 "ip": "192.168.2.1",
#                 "cores": "8",
#                 "ram": "32",
#                 "disk": "10",
#                 "static_routes": []
#             }
#         },
#         {
#             "name": "tacc",
#             "site": "TACC",
#             "facility": "FABRIC",
#             "subnet": "192.168.3.0/24",
#             "router": {
#                 "name": "tacc_router",
#                 "facility": "FABRIC",
#                 "network": "tacc",
#                 "site": "TACC",
#                 "ip": "192.168.3.1",
#                 "cores": "8",
#                 "ram": "32",
#                 "disk": "10",
#                 "static_routes": []
#             }
#         },
#         {
#             "name": "utah",
#             "site": "UTAH",
#             "facility": "FABRIC",
#             "subnet": "192.168.4.0/24",
#             "router": {
#                 "name": "utah_router",
#                 "facility": "FABRIC",
#                 "network": "utah",
#                 "site": "UTAH",
#                 "ip": "192.168.4.1",
#                 "cores": "8",
#                 "ram": "32",
#                 "disk": "10",
#                 "static_routes": []
#             }
#         }
#     ],
#     "links": [
#         {
#             "name": "link0",
#             "subnet": "192.168.100.0/24",
#             "endpoints": [
#                 {
#                     "router_name": "dall_router",
#                     "ip": "192.168.100.1"
#                 },
#                 {
#                     "router_name": "chameleon_router",
#                     "ip": "192.168.100.2"
#                 }
#             ]
#         },
#         {
#             "name": "link1",
#             "subnet": "192.168.101.0/24",
#             "endpoints": [
#                 {
#                     "router_name": "dall_router",
#                     "ip": "192.168.101.1"
#                 },
#                 {
#                     "router_name": "utah_router",
#                     "ip": "192.168.101.2"
#                 }
#             ]
#         },
#         {
#             "name": "link2",
#             "subnet": "192.168.102.0/24",
#             "endpoints": [
#                 {
#                     "router_name": "utah_router",
#                     "ip": "192.168.102.1"
#                 },
#                 {
#                     "router_name": "chameleon_router",
#                     "ip": "192.168.102.2"
#                 }
#             ]
#         },
#         {
#             "name": "link3",
#             "subnet": "192.168.103.0/24",
#             "endpoints": [
#                 {
#                     "router_name": "tacc_router",
#                     "ip": "192.168.103.1"
#                 },
#                 {
#                     "router_name": "dall_router",
#                     "ip": "192.168.103.2"
#                 }
#             ]
#         }
#     ],
#     "nodes": [
#         {
#             "name": "chameleon_node0",
#             "facility": "CHI@UC",
#             "compute_reservation_id": "b5f55afa-c78a-423f-a23e-ad5c7ff3bfa5",
#             "network": "chameleon",
#             "ip": "192.168.1.249",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.1.1"
#                 ]
#             ],
#             "management_ip": "192.5.86.227"
#         },
#         {
#             "name": "chameleon_node1",
#             "facility": "CHI@UC",
#             "compute_reservation_id": "b5f55afa-c78a-423f-a23e-ad5c7ff3bfa5",
#             "network": "chameleon",
#             "ip": "192.168.1.221",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.1.1"
#                 ]
#             ],
#             "management_ip": "192.5.87.210"
#         },
#         {
#             "name": "dall_node1",
#             "facility": "FABRIC",
#             "network": "dall",
#             "ip": "192.168.1.100",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.2.1"
#                 ]
#             ]
#         },
#         {
#             "name": "dall_node2",
#             "facility": "FABRIC",
#             "network": "dall",
#             "ip": "192.168.1.101",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.2.1"
#                 ]
#             ]
#         },
#         {
#             "name": "tacc_node1",
#             "facility": "FABRIC",
#             "network": "tacc",
#             "ip": "192.168.2.100",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.3.1"
#                 ]
#             ]
#         },
#         {
#             "name": "tacc_node2",
#             "facility": "FABRIC",
#             "network": "tacc",
#             "ip": "192.168.2.101",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.3.1"
#                 ]
#             ]
#         },
#         {
#             "name": "utah_node1",
#             "facility": "FABRIC",
#             "network": "utah",
#             "ip": "192.168.3.100",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.4.1"
#                 ]
#             ]
#         },
#         {
#             "name": "utah_node2",
#             "facility": "FABRIC",
#             "network": "utah",
#             "ip": "192.168.3.101",
#             "cores": "8",
#             "ram": "32",
#             "disk": "10",
#             "static_routes": [
#                 [
#                     "192.168.0.0/16",
#                     "192.168.4.1"
#                 ]
#             ]
#         }
#     ]
# }

# %%
#frr_experiment.submit()

# %%
frr_experiment.deploy()
# Out:
# Submit FABRIC Slice...
# Wait for all nodes...
# Deploy Node Tools...

# %% [markdown]
# ## Run the GUI and Interact with the Experiment

# %%
#frr_experiment.load()
#print(f"here")
frr_experiment.display()

# %% [markdown]
# ## Step 9: Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
#raise Exception()

# %%
#try:
#    #frr_experiment.fablib.delete_all()
#    slice.delete()
#except Exception as e:
#    print(f"Exception: {e}")
