# %%
                    
import json

file_name='config/sites_test.json'

ffr_config = { 'slice': {}, 
               'networks': [],
               'links': [], 
                'nodes': []}


sites = [ 'DALL', 'TACC', 'UTAH', 'WASH' ]
links = [ ('DALL','WASH'),
         ('DALL','UTAH'),
         ('UTAH','WASH'),
         ('TACC','DALL'),
        ]
nodes_per_site=2

for site in sites:
    subnet= f'192.168.{sites.index(site)+1}.0/24'
    gw_ip= f'192.168.{sites.index(site)+1}.1'
    ffr_config['networks'].append({'name': site.lower(), 
                                    'site': site, 
                                    'subnet': subnet,
                                    'router' : {   'name': f'{ site.lower()}_router', 
                                                   'facility': 'FABRIC',
                                                   'network': site.lower(), 
                                                   'ip': gw_ip, 
                                                   'cores': '8', 'ram': '32', 'disk': '10',
                                                   'static_routes': [ ] }
                                  })
    
    for n in range( nodes_per_site):
        ffr_config['nodes'].append({   'name': f'{site.lower()}_node{n+1}', 
                                       'facility': 'FABRIC',
                                       'network': f'{site.lower()}', 
                                       'ip': f'192.168.{sites.index(site)+1}.{n+100}', 
                                       'cores': '8', 'ram': '32', 'disk': '10',
                                       'static_routes': [ ('192.168.0.0/16', gw_ip) ] 
                                   })


for link in links:                                   
    ffr_config['links'].append({'name': f'link{links.index(link)}', 
                                'subnet': f'192.168.{links.index(link)+100}.0/24',
                                'endpoints': ({'router_name': f'{link[0].lower()}_router', 'ip': f'192.168.{links.index(link)+100}.1' }, 
                                              {'router_name': f'{link[1].lower()}_router', 'ip': f'192.168.{links.index(link)+100}.2' }) 
                               } )
                                   

                                   
                                   



json_object = json.dumps(ffr_config, indent=4)
 
# Writing to sample.json
with open(file_name, "w") as outfile:
    outfile.write(json_object)

#print(f"{list(map(lambda x: x['name'], ffr_config['links']))}")

#print(f"{json.dumps(ffr_config, indent = 4)}")
            
#frr_experiment = FRRouting_Experiment('FRRouting_OSPF_SC22', config=ffr_config)

# %%
import json

file_name='config/sites_5.json'

ffr_config = {
    'networks' : [ {'name': 'dall', 
                    'site': 'DALL', 
                    'subnet': '192.168.1.0/24',
                    'router' : {   'name': 'dall_router', 
                                   'facility': 'FABRIC',
                                   'network': 'dall', 
                                   'ip': '192.168.1.1', 
                                   'cores': '32', 'ram': '128', 'disk': '10',
                                   'static_routes': [ ] }
                   }, 
                   {'name': 'salt', 
                    'site': 'SALT',  
                    'subnet': '192.168.2.0/24',
                    'router' : {   'name': 'salt_router', 
                                   'facility': 'FABRIC',
                                   'network': 'dall', 
                                   'ip': '192.168.2.1', 
                                   'cores': '32', 'ram': '128', 'disk': '10',
                                   'static_routes': [ ] }
                   }, 
                  {'name': 'utah', 
                    'site': 'UTAH',  
                    'subnet': '192.168.3.0/24',
                    'router' : {   'name': 'utah_router', 
                                   'facility': 'FABRIC',
                                   'network': 'dall', 
                                   'ip': '192.168.3.1', 
                                   'cores': '32', 'ram': '128', 'disk': '10',
                                   'static_routes': [ ] }
                   }, 
                  {'name': 'wash', 
                    'site': 'WASH',  
                    'subnet': '192.168.4.0/24',
                    'router' : {   'name': 'wash_router', 
                                   'facility': 'FABRIC',
                                   'network': 'dall', 
                                   'ip': '192.168.4.1', 
                                   'cores': '32', 'ram': '128', 'disk': '10',
                                   'static_routes': [ ] }
                   }, 
                 ],


    'links': [ {'name': 'link1', 
                'subnet': '192.168.101.0/24',
                'endpoints': ({'router_name': 'dall_router', 'ip': '192.168.101.1' }, 
                              {'router_name': 'salt_router', 'ip': '192.168.101.2' }) 
               } ,
              {'name': 'link2', 
                'subnet': '192.168.102.0/24',
                'endpoints': ({'router_name': 'dall_router', 'ip': '192.168.102.1' }, 
                              {'router_name': 'wash_router', 'ip': '192.168.102.2' }) 
               } ,
              {'name': 'link3', 
                'subnet': '192.168.103.0/24',
                'endpoints': ({'router_name': 'wash_router', 'ip': '192.168.103.1' }, 
                              {'router_name': 'salt_router', 'ip': '192.168.103.2' }) 
               } ,
              {'name': 'link4', 
                'subnet': '192.168.104.0/24',
                'endpoints': ({'router_name': 'utah_router', 'ip': '192.168.104.1' }, 
                              {'router_name': 'salt_router', 'ip': '192.168.104.2' }) 
               } ,
             ],

    'nodes' : [ {      'name': 'dall_node1', 
                       'facility': 'FABRIC',
                       'network': 'dall', 
                       'ip': '192.168.1.100', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16','192.168.1.1') ] },
                   
                    {  'name': 'dall_node2', 
                       'facility': 'FABRIC',
                       'network': 'dall', 
                       'ip': '192.168.1.101', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16', '192.168.1.1') ] }, 
               
               {      'name': 'salt_node1', 
                       'facility': 'FABRIC',
                       'network': 'salt', 
                       'ip': '192.168.2.100', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16','192.168.2.1') ] },
                    {  'name': 'salt_node2', 
                       'facility': 'FABRIC',
                       'network': 'salt', 
                       'ip': '192.168.2.101', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16', '192.168.2.1') ] }, 
               
               {      'name': 'utah_node1', 
                       'facility': 'FABRIC',
                       'network': 'utah', 
                       'ip': '192.168.3.100', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16','192.168.3.1') ] }, 
                    {  'name': 'utah_node2', 
                       'facility': 'FABRIC',
                       'network': 'utah', 
                       'ip': '192.168.3.101', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16', '192.168.3.1') ] },
               
               {      'name': 'wash_node1', 
                       'facility': 'FABRIC',
                       'network': 'wash', 
                       'ip': '192.168.4.100', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16','192.168.4.1') ] },
                    {  'name': 'wash_node2', 
                       'facility': 'FABRIC',
                       'network': 'wash', 
                       'ip': '192.168.4.101', 
                       'cores': '32', 'ram': '128', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16', '192.168.4.1') ] },
               
                  ]
}


json_object = json.dumps(ffr_config, indent=4)
 
# Writing to sample.json
with open(file_name, "w") as outfile:
    outfile.write(json_object)

#print(f"{list(map(lambda x: x['name'], ffr_config['links']))}")

#print(f"{json.dumps(ffr_config, indent = 4)}")
            
#frr_experiment = FRRouting_Experiment('FRRouting_OSPF_SC22', config=ffr_config)

# %%
import json

file_name='config/new.json'

ffr_config = {
    'networks' : [ {'name': 'dall', 
                    'site': 'DALL', 
                    'subnet': '192.168.1.0/24',
                    'router' : {   'name': 'dall_router', 
                                   'facility': 'FABRIC',
                                   'network': 'dall', 
                                   'ip': '192.168.1.1', 
                                   'cores': '8', 'ram': '32', 'disk': '10',
                                   'static_routes': [ ] }
                   }, 
                    
                   {'name': 'salt', 
                    'site': 'SALT',  
                    'subnet': '192.168.3.0/24',
                    'router' : {   'name': 'salt_router', 
                                   'facility': 'FABRIC',
                                   'network': 'dall', 
                                   'ip': '192.168.2.1', 
                                   'cores': '8', 'ram': '32', 'disk': '10',
                                   'static_routes': [ ] }
                   },         
        
                    ],


    'links': [ {'name': 'link1', 
                'subnet': '192.168.100.0/24',
                'endpoints': ({'router_name': 'dall_router', 'ip': '192.168.100.1' }, 
                              {'router_name': 'salt_router', 'ip': '192.168.100.2' }) 
               } ,
                 ],

    'nodes' : [ {      'name': 'node1', 
                       'facility': 'FABRIC',
                       'network': 'dall', 
                       'ip': '192.168.1.100', 
                       'cores': '8', 'ram': '32', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16','192.168.1.1') ] },
                   
                    {  'name': 'node2', 
                       'facility': 'FABRIC',
                       'network': 'salt', 
                       'ip': '192.168.2.100', 
                       'cores': '8', 'ram': '32', 'disk': '10',
                       'static_routes': [ ('192.168.0.0/16', '192.168.2.1') ] }, 
                  ]
}


json_object = json.dumps(ffr_config, indent=4)
 
# Writing to sample.json
with open(file_name, "w") as outfile:
    outfile.write(json_object)

#print(f"{list(map(lambda x: x['name'], ffr_config['links']))}")

#print(f"{json.dumps(ffr_config, indent = 4)}")
            
#frr_experiment = FRRouting_Experiment('FRRouting_OSPF_SC22', config=ffr_config)
