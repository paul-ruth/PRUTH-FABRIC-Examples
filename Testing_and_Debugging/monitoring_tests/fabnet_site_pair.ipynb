# %% [markdown]
# # FABRIC Experiment
#
# FABRIC provides a pair of layer 3 IP networking services across every FABRIC site (FABnetv4 and FABnetv6). You can think of this service as a private internet that connects experiments across the testbed using FABRIC's high-performance network links.
#
# This notebook describes how to use the FABnetv4 service which is FABRIC's private IPv4 internet.

# %%
import os
import sys
import time
from datetime import datetime
from dateutil import tz


module_path = os.path.abspath(os.path.join(f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fablib_local"))
if module_path not in sys.path:
    sys.path.append(module_path)
#from fablib_custom.fablib_custom import *

#from my_experiment.fabnet_pairs import MyExperiment
from my_experiment.fabnet_single import MyExperiment

#fablib = fablib_manager(output_type='HTML')

# %%
from concurrent.futures import ThreadPoolExecutor
import time



thread_pool_size = 5
thread_delay = 20
thread_count = 20


test_site='MAX'
test_base_name=f'{test_site}a'
target_ip='10.133.134.2'

thread_pool_executor = ThreadPoolExecutor(thread_pool_size)

count=0

threads = {}
for i in range(thread_count):
    count = count + 1
    print(f"Create thread: {i}")
    threads[f'{i}'] = thread_pool_executor.submit(   MyExperiment.deploy_and_run, 
                                                     f'{test_base_name}{i}',
                                                     output=None,
                                                     site1=test_site,
                                                     #site2='WASH',
                                                     #host1='star-w4.fabric-testbed.net',
                                                     #host2='wash-w2.fabric-testbed.net',
                                                     node_cores=2, 
                                                     node_ram=8, 
                                                     node_disk=10, 
                                                     target_ip=target_ip,
                                                     delete=False,
                                                     nic_type='NIC_Basic',
                                                     avoid=['FIU','CLEM','UCSD','GPN'],
                                                     node_tools_dir=f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fabric_node_tools")
    if count < thread_pool_size:
        time.sleep(thread_delay)

for thread_id,thread in threads.items():
    try:
        result = thread.result()
    except Exception as e:
        print(f"{thread_id}, exception: {e}")
        result  = f"{e}"
        time.sleep(20)
        
    print(f"{thread_id},{result}")
    # Append-adds at last
    file1 = open("results.txt", "a")  # append mode
    file1.write(f"{thread_id}: {result}\n")
    file1.close()
# Out:
# Create thread: 0
# Creating: MAXa0
# Create thread: 1
# Creating: MAXa1
# MAXa1:  site1 MAX, host1: max-w1.fabric-testbed.net
# Create thread: 2
# Creating: MAXa2
# MAXa2:  site1 MAX, host1: max-w5.fabric-testbed.net
# MAXa0:  site1 MAX, host1: max-w3.fabric-testbed.net
# Create thread: 3
# Creating: MAXa3
# MAXa3:  site1 MAX, host1: max-w1.fabric-testbed.net
# Create thread: 4
# Create thread: 5
# Create thread: 6
# Create thread: 7
# Create thread: 8
# Create thread: 9
# Create thread: 10
# Create thread: 11
# Create thread: 12
# Create thread: 13
# Create thread: 14
# Create thread: 15
# Create thread: 16
# Create thread: 17
# Create thread: 18
# Create thread: 19
# Creating: MAXa4
# MAXa4:  site1 MAX, host1: max-w1.fabric-testbed.net
# Creating: MAXa5
# MAXa5:  site1 MAX, host1: max-w3.fabric-testbed.net
# 0,MAXa0,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.7.0/24,0000:e2:0b.5,fail,
# 1,MAXa1,10.133.134.2,MAX,max-w1.fabric-testbed.net,10.130.5.0/24,0000:a1:00.4,fail,
# Creating: MAXa6
# MAXa6:  site1 MAX, host1: max-w4.fabric-testbed.net
# Creating: MAXa7
# MAXa7:  site1 MAX, host1: max-w4.fabric-testbed.net
# 2,MAXa2,10.133.134.2,MAX,max-w5.fabric-testbed.net,10.130.6.0/24,0000:e2:0e.4,success,
# 3,MAXa3,10.133.134.2,MAX,max-w1.fabric-testbed.net,10.130.8.0/24,0000:a1:04.4,success,
# Creating: MAXa8
# MAXa8:  site1 MAX, host1: max-w4.fabric-testbed.net
# 4,MAXa4,10.133.134.2,MAX,max-w1.fabric-testbed.net,10.130.9.0/24,0000:a1:0b.2,fail,
# Creating: MAXa9
# MAXa9:  site1 MAX, host1: max-w3.fabric-testbed.net
# 5,MAXa5,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.10.0/24,0000:e2:08.6,fail,
# Creating: MAXa10
# MAXa10:  site1 MAX, host1: max-w3.fabric-testbed.net
# Creating: MAXa11
# MAXa11:  site1 MAX, host1: max-w3.fabric-testbed.net
# Creating: MAXa12
# MAXa12:  site1 MAX, host1: max-w5.fabric-testbed.net
# Creating: MAXa13
# MAXa13:  site1 MAX, host1: max-w3.fabric-testbed.net
# 6,MAXa6,10.133.134.2,MAX,max-w4.fabric-testbed.net,10.130.11.0/24,0000:e2:08.6,fail,
# 7,MAXa7,10.133.134.2,MAX,max-w4.fabric-testbed.net,10.130.12.0/24,0000:e2:0b.7,fail,
# 8,MAXa8,10.133.134.2,MAX,max-w4.fabric-testbed.net,10.130.13.0/24,0000:e2:02.2,fail,
# 9,MAXa9,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.14.0/24,0000:e2:08.2,fail,
# Creating: MAXa14
# MAXa14:  site1 MAX, host1: max-w3.fabric-testbed.net
# Creating: MAXa15
# MAXa15:  site1 MAX, host1: max-w3.fabric-testbed.net
# 10,MAXa10,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.15.0/24,0000:e2:01.4,fail,
# Creating: MAXa16
# MAXa16:  site1 MAX, host1: max-w2.fabric-testbed.net
# 11,MAXa11,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.16.0/24,0000:e2:09.1,fail,
# 12,MAXa12,10.133.134.2,MAX,max-w5.fabric-testbed.net,10.130.17.0/24,0000:e2:0d.1,fail,
# Creating: MAXa17
# MAXa17:  site1 MAX, host1: max-w1.fabric-testbed.net
# Creating: MAXa18
# MAXa18:  site1 MAX, host1: max-w2.fabric-testbed.net
# 13,MAXa13,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.18.0/24,0000:e2:0f.2,fail,
# 14,MAXa14,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.19.0/24,0000:e2:0a.6,fail,
# Creating: MAXa19
# MAXa19:  site1 MAX, host1: max-w4.fabric-testbed.net
# 15,MAXa15,10.133.134.2,MAX,max-w3.fabric-testbed.net,10.130.20.0/24,0000:e2:08.1,fail,
# 16,MAXa16,10.133.134.2,MAX,max-w2.fabric-testbed.net,10.130.21.0/24,0000:a1:0a.0,fail,
# 17,MAXa17,10.133.134.2,MAX,max-w1.fabric-testbed.net,10.130.22.0/24,0000:a1:0a.5,fail,
# 18,MAXa18,10.133.134.2,MAX,max-w2.fabric-testbed.net,10.130.23.0/24,0000:a1:04.0,fail,
# 19,MAXa19,10.133.134.2,MAX,max-w4.fabric-testbed.net,10.130.24.0/24,0000:e2:07.5,fail,

# %%
results = MyExperiment.deploy_and_run('test1',
                     output=None,
                     #site1='STAR',
                     #site2='WASH',
                     #host1='star-w4.fabric-testbed.net',
                     #host2='wash-w2.fabric-testbed.net',
                     node_cores=2, 
                     node_ram=8, 
                     node_disk=10, 
                     nic_type='NIC_Basic',
                     avoid=['FIU','CLEM','UCSD','GPN'],
                     node_tools_dir=f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fabric_node_tools")



# Append-adds at last
file1 = open("results.txt", "a")  # append mode
file1.write(f"{results}")
file1.close()

# %%
#run_name=f'iperf3_test_{time_stamp}'
#print(f"run_name: {run_name}")
#sites=['MICH','NCSA', 'DALL','TACC','UTAH','SALT','STAR','WASH','MASS','MAX']
#sites=['MICH', 'DALL','TACC','UTAH','SALT','STAR','WASH','MASS','MAX']
sites=['UTAH','DALL']

my_experiment = MyExperiment('test1',
                             output=None,
                             #site1='STAR',
                             #site2='WASH',
                             #host1='star-w4.fabric-testbed.net',
                             #host2='wash-w2.fabric-testbed.net',
                             node_cores=2, 
                             node_ram=8, 
                             node_disk=10, 
                             nic_type='NIC_Basic',
                             avoid=['FIU','CLEM','UCSD','GPN'],
                             node_tools_dir=f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fabric_node_tools")

# %%
my_experiment.deploy()
#my_experiment.load(run_name)

# %%
my_experiment.configure()

# %%
my_experiment.run()

# %%
from IPython.display import clear_output
from concurrent.futures import ThreadPoolExecutor

thread_pool_executor = ThreadPoolExecutor(1)
    

runs = [ 
        ('UTAH','DALL'), ('DALL','UTAH'),   
        #('SALT','UTAH'), ('UTAH','SALT'),
        #('SALT','STAR'), ('STAR','SALT'),
        #('SALT','DALL'), ('DALL','SALT'),   
        #('DALL','STAR'), ('STAR','DALL'),
        #('WASH','STAR'), ('STAR','WASH'),
        #('WASH','DALL'), ('DALL','WASH'),
        #('NCSA','STAR'), ('STAR','NCSA'),
        #('MICH','STAR'), ('STAR','MICH'),
        ]
    
threads = {}
for run in runs:
    threads[run] = thread_pool_executor.submit(my_experiment.run,runs=[run], 
                 O=10, w='32M', P=8, t=20, i=10) 
   
 
while len(threads) > 0:
    for run,thread in threads.items():
        if thread.done():
            del threads[run]
            clear_output(wait=True)
            my_experiment.results()
            break
    time.sleep(10)
print(f"done!")
#my_experiment.run(run_name=f'run1', runs=runs, 
#                  O=10, w='32M', P=8, t=70, i=10)
clear_output(wait=True)
my_experiment.results()

# %%
my_experiment.clean_up()
