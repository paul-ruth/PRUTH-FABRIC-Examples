# %% [markdown]
# # FABRIC Experiment
#
# FABRIC provides a pair of layer 3 IP networking services across every FABRIC site (FABnetv4 and FABnetv6). You can think of this service as a private internet that connects experiments across the testbed using FABRIC's high-performance network links.
#
# This notebook describes how to use the FABnetv4 service which is FABRIC's private IPv4 internet.

# %%
import os
import sys
import time
from datetime import datetime
from dateutil import tz


module_path = os.path.abspath(os.path.join(f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fablib_local"))
if module_path not in sys.path:
    sys.path.append(module_path)
#from fablib_custom.fablib_custom import *

#from my_experiment.fabnet_pairs import MyExperiment
from my_experiment.fabnet_single import MyExperiment

#fablib = fablib_manager(output_type='HTML')

# %%
from concurrent.futures import ThreadPoolExecutor
import time



thread_pool_size = 5
thread_delay = 10
thread_count = 20
delete=False

test_site='MAX'
test_base_name=f'{test_site}s'
target_ip='10.133.132.2'

thread_pool_executor = ThreadPoolExecutor(thread_pool_size)

count=0

threads = {}
for i in range(thread_count):
    count = count + 1
    print(f"Create thread: {i}")
    threads[f'{i}'] = thread_pool_executor.submit(   MyExperiment.deploy_and_run, 
                                                     f'{test_base_name}{i}',
                                                     output=None,
                                                     site1=test_site,
                                                     #site2='WASH',
                                                     #host1='star-w4.fabric-testbed.net',
                                                     #host2='wash-w2.fabric-testbed.net',
                                                     node_cores=2, 
                                                     node_ram=8, 
                                                     node_disk=10, 
                                                     target_ip=target_ip,
                                                     delete=delete,
                                                     nic_type='NIC_Basic',
                                                     avoid=['FIU','CLEM','UCSD','GPN'],
                                                     node_tools_dir=f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fabric_node_tools")
    if count < thread_pool_size:
        time.sleep(thread_delay)

for thread_id,thread in threads.items():
    try:
        result = thread.result()
    except Exception as e:
        print(f"{thread_id}, exception: {e}")
        result  = f"{e}"
        time.sleep(20)
        
    print(f"{thread_id},{result}")
    # Append-adds at last
    file1 = open("results.txt", "a")  # append mode
    file1.write(f"{thread_id}: {result}\n")
    file1.close()
# Out:
# Create thread: 0
# Creating: MAXs0
# MAXs0:  site1 MAX, host1: max-w4.fabric-testbed.net
# Create thread: 1
# Creating: MAXs1
# MAXs1:  site1 MAX, host1: max-w2.fabric-testbed.net
# Create thread: 2
# Creating: MAXs2
# MAXs2:  site1 MAX, host1: max-w2.fabric-testbed.net
# Create thread: 3
# Creating: MAXs3
# MAXs3:  site1 MAX, host1: max-w5.fabric-testbed.net
# Create thread: 4
# Create thread: 5
# Create thread: 6
# Create thread: 7
# Create thread: 8
# Create thread: 9
# Create thread: 10
# Create thread: 11
# Create thread: 12
# Create thread: 13
# Create thread: 14
# Create thread: 15
# Create thread: 16
# Create thread: 17
# Create thread: 18
# Create thread: 19
# Creating: MAXs4
# MAXs4:  site1 MAX, host1: max-w4.fabric-testbed.net
# 0,MAXs0,10.133.132.2,MAX,max-w4.fabric-testbed.net,10.130.2.0/24,0000:e2:0b.0,success,
# Creating: MAXs5
# MAXs5:  site1 MAX, host1: max-w2.fabric-testbed.net
# 1,MAXs1,10.133.132.2,MAX,max-w2.fabric-testbed.net,10.130.3.0/24,0000:a1:00.2,success,
# Creating: MAXs6
# MAXs6:  site1 MAX, host1: max-w5.fabric-testbed.net
# 2,MAXs2,10.133.132.2,MAX,max-w2.fabric-testbed.net,10.130.4.0/24,0000:a1:03.3,success,
# Creating: MAXs7
# MAXs7:  site1 MAX, host1: max-w5.fabric-testbed.net
# 3,MAXs3,10.133.132.2,MAX,max-w5.fabric-testbed.net,10.130.5.0/24,0000:e2:0e.4,success,
# Creating: MAXs8
# MAXs8:  site1 MAX, host1: max-w2.fabric-testbed.net
# 4,MAXs4,10.133.132.2,MAX,max-w4.fabric-testbed.net,10.130.6.0/24,0000:e2:0b.1,success,
# Creating: MAXs9
# MAXs9:  site1 MAX, host1: max-w5.fabric-testbed.net
# Creating: MAXs10
# MAXs10:  site1 MAX, host1: max-w1.fabric-testbed.net
# 5,MAXs5,10.133.132.2,MAX,max-w2.fabric-testbed.net,10.130.8.0/24,0000:a1:05.5,success,
# Creating: MAXs11
# MAXs11:  site1 MAX, host1: max-w4.fabric-testbed.net
# 6,MAXs6,10.133.132.2,MAX,max-w5.fabric-testbed.net,10.130.9.0/24,0000:e2:0d.1,success,
# 7,MAXs7,10.133.132.2,MAX,max-w5.fabric-testbed.net,10.130.10.0/24,0000:e2:0f.0,fail,
# Creating: MAXs12
# MAXs12:  site1 MAX, host1: max-w2.fabric-testbed.net
# Creating: MAXs13
# MAXs13:  site1 MAX, host1: max-w1.fabric-testbed.net
# 8,MAXs8,10.133.132.2,MAX,max-w2.fabric-testbed.net,10.130.11.0/24,0000:a1:0a.0,success,
# 9,MAXs9,10.133.132.2,MAX,max-w5.fabric-testbed.net,10.130.12.0/24,0000:e2:07.5,success,
# Creating: MAXs14
# MAXs14:  site1 MAX, host1: max-w2.fabric-testbed.net
# Exception: failed lease update- all units failed priming: Exception during create for unit: 5b8706b1-59e2-436a-9051-0146ac59debd Playbook has failed tasks: NSO commit returned JSON-RPC error: type: rpc.method.failed, code: -32000, message: Method failed, data: message: External error in the NED implementation for device max-data-sw: Fri Oct 21 22:00:44.427 UTC Failed to commit one or more configuration items during a pseudo-atomic operation. All changes made have been reverted.  SEMANTIC ERRORS: This configuration was rejected by  the system due to semantic errors. The individual  errors with each failed configuration command can be  found below.l2vpn bridge group bg-MAX_net1-5b8706b1-59e2-436a-  bridge-domain bd-MAX_net1-5b8706b1-59e2-4   interface HundredGigE0/0/0/5.2002 Invalid argument: Interface already used for L2VPN      end, internal: jsonrpc_tx_commit357
# configure: Exception: local variable 'network1_available_ips' referenced before assignment
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_16237/489100212.py in <module>
#      41 for thread_id,thread in threads.items():
#      42     try:
# ---> 43         result = thread.result()
#      44     except Exception as e:
#      45         print(f"{thread_id}, exception: {e}")
#
# /opt/conda/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /opt/conda/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
# DEBUG:root:adding IP 253
# DEBUG:root:adding IP 254
# DEBUG:root:adding IP 255
# Creating: MAXs15
# MAXs15:  site1 MAX, host1: max-w5.fabric-testbed.net
# Creating: MAXs16
# MAXs16:  site1 MAX, host1: max-w4.fabric-testbed.net
# Creating: MAXs17
# MAXs17:  site1 MAX, host1: max-w4.fabric-testbed.net
# Creating: MAXs18
# Creating: MAXs19
# MAXs18:  site1 MAX, host1: max-w3.fabric-testbed.net
# MAXs19:  site1 MAX, host1: max-w3.fabric-testbed.net

# %%
results = MyExperiment.deploy_and_run('test1',
                     output=None,
                     #site1='STAR',
                     #site2='WASH',
                     #host1='star-w4.fabric-testbed.net',
                     #host2='wash-w2.fabric-testbed.net',
                     node_cores=2, 
                     node_ram=8, 
                     node_disk=10, 
                     nic_type='NIC_Basic',
                     avoid=['FIU','CLEM','UCSD','GPN'],
                     node_tools_dir=f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fabric_node_tools")



# Append-adds at last
file1 = open("results.txt", "a")  # append mode
file1.write(f"{results}")
file1.close()

# %%
#run_name=f'iperf3_test_{time_stamp}'
#print(f"run_name: {run_name}")
#sites=['MICH','NCSA', 'DALL','TACC','UTAH','SALT','STAR','WASH','MASS','MAX']
#sites=['MICH', 'DALL','TACC','UTAH','SALT','STAR','WASH','MASS','MAX']
sites=['UTAH','DALL']

my_experiment = MyExperiment('test1',
                             output=None,
                             #site1='STAR',
                             #site2='WASH',
                             #host1='star-w4.fabric-testbed.net',
                             #host2='wash-w2.fabric-testbed.net',
                             node_cores=2, 
                             node_ram=8, 
                             node_disk=10, 
                             nic_type='NIC_Basic',
                             avoid=['FIU','CLEM','UCSD','GPN'],
                             node_tools_dir=f"{os.environ['HOME']}/work/PRUTH-FABRIC-Examples/fabric_node_tools")

# %%
my_experiment.deploy()
#my_experiment.load(run_name)

# %%
my_experiment.configure()

# %%
my_experiment.run()

# %%
from IPython.display import clear_output
from concurrent.futures import ThreadPoolExecutor

thread_pool_executor = ThreadPoolExecutor(1)
    

runs = [ 
        ('UTAH','DALL'), ('DALL','UTAH'),   
        #('SALT','UTAH'), ('UTAH','SALT'),
        #('SALT','STAR'), ('STAR','SALT'),
        #('SALT','DALL'), ('DALL','SALT'),   
        #('DALL','STAR'), ('STAR','DALL'),
        #('WASH','STAR'), ('STAR','WASH'),
        #('WASH','DALL'), ('DALL','WASH'),
        #('NCSA','STAR'), ('STAR','NCSA'),
        #('MICH','STAR'), ('STAR','MICH'),
        ]
    
threads = {}
for run in runs:
    threads[run] = thread_pool_executor.submit(my_experiment.run,runs=[run], 
                 O=10, w='32M', P=8, t=20, i=10) 
   
 
while len(threads) > 0:
    for run,thread in threads.items():
        if thread.done():
            del threads[run]
            clear_output(wait=True)
            my_experiment.results()
            break
    time.sleep(10)
print(f"done!")
#my_experiment.run(run_name=f'run1', runs=runs, 
#                  O=10, w='32M', P=8, t=70, i=10)
clear_output(wait=True)
my_experiment.results()

# %%
my_experiment.clean_up()
